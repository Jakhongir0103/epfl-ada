# %% [markdown]
# ### Welcome to the exercise about observational studies! This exercise will be hands on, and you will be able to practise the skills you developed so far!

# %% [markdown]
# ## Propensity score matching
#
# In this exercise, you will apply [propensity score matching](http://www.stewartschultz.com/statistics/books/Design%20of%20observational%20studies.pdf), which we discussed in lecture 6 ("Observational studies"), in order to draw conclusions from an observational study.
#
# We will work with a by-now classic dataset from Robert LaLonde's study "[Evaluating the Econometric Evaluations of Training Programs](http://people.hbs.edu/nashraf/LaLonde_1986.pdf)" (1986).
# The study investigated the effect of a job training program ("National Supported Work Demonstration") on the real earnings of an individual, a couple of years after completion of the program.
# Your task is to determine the effectiveness of the "treatment" represented by the job training program.

# %% [markdown]
# #### Dataset description
#
# - `treat`: 1 if the subject participated in the job training program, 0 otherwise
# - `age`: the subject's age
# - `educ`: years of education
# - `race`: categorical variable with three possible values: Black, Hispanic, or White
# - `married`: 1 if the subject was married at the time of the training program, 0 otherwise
# - `nodegree`: 1 if the subject has earned no school degree, 0 otherwise
# - `re74`: real earnings in 1974 (pre-treatment)
# - `re75`: real earnings in 1975 (pre-treatment)
# - `re78`: real earnings in 1978 (outcome)

# %% [markdown]
# If you want to deepen your knowledge on propensity scores and observational studies, we highly recommend Rosenbaum's excellent book on the ["Design of Observational Studies"](http://www.stewartschultz.com/statistics/books/Design%20of%20observational%20studies.pdf). Even just reading the first chapter (18 pages) will help you a lot.

# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import statsmodels.formula.api as smf
# %matplotlib inline

data_folder = './data/'
df = pd.read_csv(data_folder + 'lalonde.csv')

# %% [markdown]
# ## 1. A naive analysis
#
# Compare the distribution of the outcome variable (`re78`) between the two groups, using plots and numbers.
# To summarize and compare the distributions, you may use the techniques we discussed in lecture 4 ("Descibing data") and 3 ("Visualizing data").
#
# What might a naive "researcher" conclude from this superficial analysis?

# %%
df_treat = df[df.treat == 1]
df_control = df[df.treat == 0]

# %%
fig, axes = plt.subplots(1, 3, figsize=(16,4))

ax0 = sns.histplot(x=df_treat['re74'], kde=True, color='blue', stat='density', label='treat', ax=axes[0])
ax0 = sns.histplot(x=df_control['re74'], kde=True, color='orange', stat='density', label='control', ax=axes[0])
ax1 = sns.histplot(x=df_treat['re75'], kde=True, color='blue', stat='density', label='treat', ax=axes[1])
ax1 = sns.histplot(x=df_control['re75'], kde=True, color='orange', stat='density', label='control', ax=axes[1])
ax2 = sns.histplot(x=df_treat['re78'], kde=True, color='blue', stat='density', label='treat', ax=axes[2])
ax2 = sns.histplot(x=df_control['re78'], kde=True, color='orange', stat='density', label='control', ax=axes[2])

ax0.set(title='Earnings density in 1974', xlabel='Earnings', ylabel='Incomde distribution')
ax1.set(title='Earnings density in 1975', xlabel='Earnings', ylabel='Incomde distribution')
ax2.set(title='Earnings density in 1978', xlabel='Earnings', ylabel='Incomde distribution')

plt.legend()
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(16,4))

ax0 = sns.boxplot(y=df['re74'],x=df.treat,ax=axes[0])
ax1 = sns.boxplot(y=df['re75'],x=df.treat,ax=axes[1])
ax2 = sns.boxplot(y=df['re78'],x=df.treat,ax=axes[2])

ax0.set(title = '1974 Earning statistics', ylabel='Earnings', xlabel='Control / Treat')
ax1.set(title = '1975 Earning statistics', ylabel='Earnings', xlabel='Control / Treat')
ax2.set(title = '1978 Earning statistics', ylabel='Earnings', xlabel='Control / Treat')

plt.show()

# %% [markdown]
# **Conclusion**\
# In 1978,
# - average salary of control was higher than that of treated group
# - density of control group was also relatively higher
#
# Which leads us to conclude that the treatment was NOT effective!
#
# `But compared to the years of 1974/1975, we have higher density for the treated people. Does it not mean that the treatment (training) was effective?`

# %% [markdown]
# ## 2. A closer look at the data
#
# You're not naive, of course (and even if you are, you've learned certain things in ADA), so you aren't content with a superficial analysis such as the above.
# You're aware of the dangers of observational studies, so you take a closer look at the data before jumping to conclusions.
#
# For each feature in the dataset, compare its distribution in the treated group with its distribution in the control group, using plots and numbers.
# As above, you may use the techniques we discussed in class for summarizing and comparing the distributions.
#
# What do you observe?
# Describe what your observations mean for the conclusions drawn by the naive "researcher" from his superficial analysis.

# %%
df.sample(2)
# Out:
#          id  treat  age  educ  black  hispan  married  nodegree      re74  \
# 253  PSID69      0   30    17      1       0        0         0  17827.37
# 177  NSW178      1   33    11      1       0        0         1      0.00
#
#          re75       re78
# 253  5546.419  14421.130
# 177  7867.916   6281.433

# %%
# treated group have more young people (under the age of 30)

ax = sns.histplot(df_treat['age'], label='treat', stat='density')
ax = sns.histplot(df_control['age'], label='control', stat='density')

ax.set_title('Age distribution')
plt.legend()
plt.show()

# %%
# More black people in treated group
# More non-married and non-hispanic people in treated group
# Less people with degree, and less people with no degree - so it should cancel out each other?

# new column on age
df.loc[df.age < 35, 'age_under_35'] = 1
df.age_under_35.fillna(0,inplace=True)
# new column on degree
df['degree'] = df.nodegree.replace({1:0,0:1})
# find percentages
df_group = df.groupby('treat')[['black','hispan','married','degree','nodegree','age_under_35']].sum()
df_group = df_group.div(df_group.sum(axis=0),axis=1)

ax = df_group.plot(kind='bar')
ax.set(xlabel='Control / Treat', ylabel='Percentage')
plt.show()

# %%
# distribution of education were pretty much same on both groups

ax = sns.boxplot(x=df.treat, y=df.educ)
ax.set(title='Education stats', xlabel='Control / Treat', ylabel='Education')

plt.show()

# %%
df.groupby('treat')[['age','educ','black','hispan','married','nodegree','re74','re75','re78']].mean()
# Out:
#              age       educ     black    hispan   married  nodegree  \
# treat
# 0      28.030303  10.235431  0.202797  0.142191  0.512821  0.596737
# 1      25.816216  10.345946  0.843243  0.059459  0.189189  0.708108
#
#               re74         re75         re78
# treat
# 0      5619.236506  2466.484443  6984.169742
# 1      2095.573689  1532.055314  6349.143530

# %% [markdown]
# ## 3. A propensity score model
#
# Use logistic regression to estimate propensity scores for all points in the dataset.
# You may use `statsmodels` to fit the logistic regression model and apply it to each data point to obtain propensity scores.
#
# Recall that the propensity score of a data point represents its probability of receiving the treatment, based on its pre-treatment features (in this case, age, education, pre-treatment income, etc.).
# To brush up on propensity scores, you may read chapter 3.3 of the above-cited book by Rosenbaum or [this article](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3144483/pdf/hmbr46-399.pdf).
#
# Note: you do not need a train/test split here. Train and apply the model on the entire dataset. If you're wondering why this is the right thing to do in this situation, recall that the propensity score model is not used in order to make predictions about unseen data. Its sole purpose is to balance the dataset across treatment groups.
# (See p. 74 of Rosenbaum's book for an explanation why slight overfitting is even good for propensity scores.
# If you want even more information, read [this article](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3144483/pdf/hmbr46-399.pdf).)

# %%
df_norm = df.copy()
df_norm['age'] = (df_norm['age'] - df_norm['age'].mean()) / df_norm['age'].var()
df_norm['educ'] = (df_norm['educ'] - df_norm['educ'].mean()) / df_norm['educ'].var()
df_norm['re74'] = (df_norm['re74'] - df_norm['re74'].mean()) / df_norm['re74'].var()
df_norm['re75'] = (df_norm['re75'] - df_norm['re75'].mean()) / df_norm['re75'].var()

model = 'treat ~ re75 + re74 + age + educ + C(black) + C(hispan) + C(married) + C(nodegree)'
ps = smf.logit(data=df_norm,formula=model).fit()

df_norm['ps'] = ps.predict()
df_norm.sample(3)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.397267
#          Iterations 14
#           id  treat       age      educ  black  hispan  married  nodegree  \
# 371  PSID187      0 -0.095897  0.105857      1       0        0         1
# 476  PSID292      0 -0.054929 -0.328416      0       0        1         1
# 230   PSID46      0 -0.075413  0.250615      1       0        1         0
#
#          re74      re75       re78  degree  age_under_35        ps
# 371 -0.000080 -0.000065  3683.9720       0           1.0  0.749493
# 476 -0.000106 -0.000197   209.8372       0           1.0  0.038375
# 230  0.000119  0.000448     0.0000       1           1.0  0.365187

# %%
### manual propensity score -> not working
"""
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

ps_values = ps.params.values[1:]
ps_manual = df_norm[['re75', 're74', 'age', 'educ', 'black', 'hispan', 'married', 'nodegree']].values @ ps_values
df_norm['ps_manual'] = sigmoid(ps_manual)

df_norm.sample(3)
""";

# %%
# The more the overlapping area, the better it is
sns.histplot(data=df_norm, x='ps', hue='treat') 
plt.show()

# %% [markdown]
# ## 4. Balancing the dataset via matching
#
# Use the propensity scores to match each data point from the treated group with exactly one data point from the control group, while ensuring that each data point from the control group is matched with at most one data point from the treated group.
# (Hint: you may explore the `networkx` package in Python for predefined matching functions.)
#
# Your matching should maximize the similarity between matched subjects, as captured by their propensity scores.
# In other words, the sum (over all matched pairs) of absolute propensity-score differences between the two matched subjects should be minimized.
#
# This is how networkx library can help you do this. Each possible pair of (treated_person, control_person) is characterized by a similarity. This is how we can initialize a graph, and add an edge for one possible pair. We then need to add an edge for each possible pair.
#     - G = nx.Graph()
#     - G.add_weighted_edges_from([(control_person, treated_person, similarity)])
# Optimal matching is then found with:
#     - matching = nx.max_weight_matching(G)
#
# After matching, you have as many treated as you have control subjects.
# Compare the outcomes (`re78`) between the two groups (treated and control).
#
# Also, compare again the feature-value distributions between the two groups, as you've done in part 2 above, but now only for the matched subjects.
# What do you observe?
# Are you closer to being able to draw valid conclusions now than you were before?

# %%
# Create a weighted graph
G = nx.Graph()

# Add weighted edges based on the similarity between propensity scores
for t in df_norm[df_norm.treat==1].index:
    for c in df_norm[df_norm.treat==0].index:

        propensity_score_t = df_norm.at[t, 'ps']
        propensity_score_c = df_norm.at[c, 'ps']

        # Define similarity
        similarity = 1 - abs(propensity_score_t - propensity_score_c)

        # Add edges
        G.add_weighted_edges_from([(t, c, similarity)])

# match
matching = nx.max_weight_matching(G)

# %%
index_1 = [match[0] for match in matching] + [match[1] for match in matching]

# %%
balanced_df_1 = df.iloc[index_1]

# %%
balanced_df_1.groupby('treat')[['age','educ','black','hispan','married','nodegree','re74','re75','re78']].mean()
# Out:
#              age       educ     black    hispan   married  nodegree  \
# treat
# 0      25.302703  10.605405  0.470270  0.216216  0.210811  0.637838
# 1      25.816216  10.345946  0.843243  0.059459  0.189189  0.708108
#
#               re74         re75        re78
# treat
# 0      2342.107564  1614.745125  5454.77605
# 1      2095.573689  1532.055314  6349.14353

# %%
# hispan, married and black columns are not well balanced

df_group = balanced_df_1.groupby('treat')[['black','hispan','married','degree','nodegree','age_under_35']].sum()
df_group = df_group.div(df_group.sum(axis=0),axis=1)

ax = df_group.plot(kind='bar')
ax.set(xlabel='Control / Treat', ylabel='Percentage')
plt.show()

# %%
# Age is still not balanced, but from above we have more or less same percentage of young people on both sides !

ax = sns.histplot(balanced_df_1[balanced_df_1.treat==1]['age'], label='treat', stat='density')
ax = sns.histplot(balanced_df_1[balanced_df_1.treat==0]['age'], label='control', stat='density')

ax.set_title('Age distribution')
plt.legend()
plt.show()

# %% [markdown]
# ## 5. Balancing the groups further
#
# Based on your comparison of feature-value distributions from part 4, are you fully satisfied with your matching?
# Would you say your dataset is sufficiently balanced?
# If not, in what ways could the "balanced" dataset you have obtained still not allow you to draw valid conclusions?
#
# Improve your matching by explicitly making sure that you match only subjects that have the same value for the problematic feature.
# Argue with numbers and plots that the two groups (treated and control) are now better balanced than after part 4.

# %%
df_treat_norm = df_norm[df_norm.treat==1]
df_control_norm = df_norm[df_norm.treat==0]

# Create a weighted graph
G = nx.Graph()

# Add weighted edges based on the similarity between propensity scores
for treat_index, treat_row in df_treat_norm.iterrows():
    for control_index, control_row in df_control_norm.iterrows():
        if treat_row['hispan'] == control_row['hispan']\
            and treat_row['black'] == control_row['black']:

            propensity_score_treat = treat_row['ps']
            propensity_score_control = control_row['ps']

            # Define similarity
            similarity = 1 - abs(propensity_score_treat - propensity_score_control)
    
            # Add edges
            G.add_weighted_edges_from([(treat_index, control_index, similarity)])

# match
matching2 = nx.max_weight_matching(G)

# %%
index_2 = [match[0] for match in matching2] + [match[1] for match in matching2]

# %%
balanced_df_2 = df.iloc[index_2]

# %%
# number of data points left
print(balanced_df_1.shape[0]) # first match
print(balanced_df_2.shape[0]) # second match
# Out:
# 370
# 232

# %%
# check mean of each column
balanced_df_2.groupby('treat')[['age','educ','black','hispan','married','nodegree','re74','re75','re78']].mean()
# Out:
#              age      educ  black    hispan   married  nodegree         re74  \
# treat
# 0      26.137931  10.37931   0.75  0.094828  0.275862  0.620690  3090.709629
# 1      25.681034  10.12069   0.75  0.094828  0.241379  0.672414  2782.527435
#
#               re75         re78
# treat
# 0      1952.238669  5095.456025
# 1      1743.704100  6166.431753

# %%
# perfectly balanced

df_group = balanced_df_2.groupby('treat')[['black','hispan','married','degree','nodegree','age_under_35']].sum()
df_group = df_group.div(df_group.sum(axis=0),axis=1)

ax = df_group.plot(kind='bar')
ax.set(xlabel='Control / Treat', ylabel='Percentage')
plt.show()

# %% [markdown]
# ## 6. A less naive analysis
#
# Compare the outcomes (`re78`) between treated and control subjects, as you've done in part 1, but now only for the matched dataset you've obtained from part 5.
# What do you conclude about the effectiveness of the job training program?

# %%
"""
df_treat = df_balanced[df_balanced.treat_matched2 == 1]
df_control = df_balanced[df_balanced.treat_matched2 == 0]

fig, axes = plt.subplots(1, 3, figsize=(16,4))

ax0 = sns.histplot(x=df_treat['re74'], kde=True, color='blue', stat='density', label='treat', ax=axes[0])
ax0 = sns.histplot(x=df_control['re74'], kde=True, color='orange', stat='density', label='control', ax=axes[0])
ax1 = sns.histplot(x=df_treat['re75'], kde=True, color='blue', stat='density', label='treat', ax=axes[1])
ax1 = sns.histplot(x=df_control['re75'], kde=True, color='orange', stat='density', label='control', ax=axes[1])
ax2 = sns.histplot(x=df_treat['re78'], kde=True, color='blue', stat='density', label='treat', ax=axes[2])
ax2 = sns.histplot(x=df_control['re78'], kde=True, color='orange', stat='density', label='control', ax=axes[2])

ax0.set(title='Earnings density in 1974', xlabel='Earnings', ylabel='Incomde distribution')
ax1.set(title='Earnings density in 1975', xlabel='Earnings', ylabel='Incomde distribution')
ax2.set(title='Earnings density in 1978', xlabel='Earnings', ylabel='Incomde distribution')

plt.legend()
plt.tight_layout()
plt.show()
""";

# %%
"""
fig, axes = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(16,4))

ax0 = sns.boxplot(y=df_balanced['re74'],x=df_balanced.treat_matched2,ax=axes[0])
ax1 = sns.boxplot(y=df_balanced['re75'],x=df_balanced.treat_matched2,ax=axes[1])
ax2 = sns.boxplot(y=df_balanced['re78'],x=df_balanced.treat_matched2,ax=axes[2])

ax0.set(title = '1974 Earning statistics', ylabel='Earnings', xlabel='Control / Treat')
ax1.set(title = '1975 Earning statistics', ylabel='Earnings', xlabel='Control / Treat')
ax2.set(title = '1978 Earning statistics', ylabel='Earnings', xlabel='Control / Treat')

plt.show()
""";

# %% [markdown]
# # Final Comparison

# %%
fig, axes = plt.subplots(1, 3, figsize=(16,4))

ax0 = sns.histplot(x=df[df.treat==1]['re78'], kde=True, color='blue', stat='density', label='treat', ax=axes[0])
ax0 = sns.histplot(x=df[df.treat==0]['re78'], kde=True, color='orange', stat='density', label='control', ax=axes[0])
ax1 = sns.histplot(x=balanced_df_1[balanced_df_1.treat==1]['re78'], kde=True, color='blue', stat='density', label='treat', ax=axes[1])
ax1 = sns.histplot(x=balanced_df_1[balanced_df_1.treat==0]['re78'], kde=True, color='orange', stat='density', label='control', ax=axes[1])
ax2 = sns.histplot(x=balanced_df_2[balanced_df_2.treat==1]['re78'], kde=True, color='blue', stat='density', label='treat', ax=axes[2])
ax2 = sns.histplot(x=balanced_df_2[balanced_df_2.treat==0]['re78'], kde=True, color='orange', stat='density', label='control', ax=axes[2])

ax0.set(title='Earnings density in 1978 (before)', xlabel='Earnings', ylabel='Incomde distribution')
ax1.set(title='Earnings density in 1978 (after 1st match)', xlabel='Earnings', ylabel='Incomde distribution')
ax2.set(title='Earnings density in 1978 (after 2nd match)', xlabel='Earnings', ylabel='Incomde distribution')

plt.legend()
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(16,6))

ax0 = sns.boxplot(y=df['re78'],x=df.treat,ax=axes[0])
ax1 = sns.boxplot(y=balanced_df_1['re78'],x=balanced_df_1.treat,ax=axes[1])
ax2 = sns.boxplot(y=balanced_df_2['re78'],x=balanced_df_2.treat,ax=axes[2])

ax0.set(title = '1978 Earning statistics (before)', ylabel='Earnings', xlabel='Control / Treat')
ax1.set(title = '1978 Earning statistics (after 1st match)', ylabel='Earnings', xlabel='Control / Treat')
ax2.set(title = '1978 Earning statistics (after 2nd match)', ylabel='Earnings', xlabel='Control / Treat')

plt.show()

# %% [markdown]
# **Here, we can clearly see that the training has been effective**
