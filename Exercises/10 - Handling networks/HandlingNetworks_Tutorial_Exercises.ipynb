# %%
import networkx as nx

import pandas as pd
from operator import itemgetter
import matplotlib.pyplot as plt
import collections
from community import community_louvain
from networkx.algorithms.community.centrality import girvan_newman
import itertools
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
nx.__version__
# Out:
# '3.1'

# %%
nx.degree(quakerG)
# Out:
# DegreeView({'George Keith': 8, 'Robert Barclay': 3, 'Benjamin Furly': 10, 'Anne Conway Viscountess Conway and Killultagh': 1, 'Franciscus Mercurius van Helmont': 2, 'William Penn': 18, 'George Fox': 22, 'George Whitehead': 13, 'William Bradford': 3, 'James Parnel': 2, 'Stephen Crisp': 3, 'Peter Collinson': 2, 'John Bartram': 2, 'James Logan': 4, 'Joseph Wyeth': 1, 'Thomas Ellwood': 8, 'Alexander Skene of Newtyle': 1, 'Lilias Skene': 1, 'Dorcas Erbery': 1, 'James Nayler': 16, 'William Mucklow': 1, 'William Dewsbury': 3, 'Edward Burrough': 9, 'John Crook': 4, 'John Audland': 6, 'John Camm': 4, 'Francis Howgill': 7, 'Edward Pyott': 2, 'Charles Marshall': 3, 'Anne Camm': 2, 'Martha Simmonds': 3, 'Richard Farnworth': 6, 'William Crouch': 2, 'Tace Sowle': 3, 'John Bellers': 1, 'Fettiplace Bellers': 1, 'William Rogers': 2, 'Hannah Stranger': 2, 'Isabel Yeamans': 1, 'George Fox the younger': 1, 'Margaret Fell': 13, 'Ellis Hookes': 1, 'William Mead': 2, 'Elizabeth Hooten': 1, 'Thomas Salthouse': 2, 'John Wilkinson': 5, 'William Coddington': 1, 'John Stubbs': 5, 'John Perrot': 7, 'Leonard Fell': 1, 'William Caton': 5, 'Samuel Fisher': 1, 'John Burnyeat': 4, 'Thomas Camm': 3, 'John Story': 6, 'Solomon Eccles': 2, 'Alexander Parker': 6, 'Isaac Norris': 1, 'John Swinton': 1, 'David Barclay of Ury': 2, 'Gervase Benson': 2, 'Robert Rich': 2, 'Anthony Pearson': 5, 'Rebecca Travers': 4, 'William Tomlinson': 2, 'Anthony Sharp': 3, 'Samuel Clarridge': 2, 'Thomas Curtis': 5, 'William Edmundson': 2, 'William Ames': 1, 'Mary Fisher': 2, 'Mary Prince': 2, 'Lydia Lancaster': 1, 'Grace Chamber': 1, 'Henry Pickworth': 1, 'Francis Bugg': 2, 'James Claypoole': 2, 'Thomas Lower': 1, 'Sarah Gibbons': 1, 'Dorothy Waugh': 1, 'John Freame': 1, 'David Barclay': 1, 'Humphrey Norton': 1, 'John Rous': 1, 'William Gibson': 1, 'Thomas Holme': 2, 'Gideon Wanton': 1, 'John Wanton': 1, 'David Lloyd': 2, 'Edward Haistwell': 1, 'John ap John': 1, 'Gilbert Latey': 2, 'Richard Hubberthorne': 2, 'Joseph Besse': 2, 'Richard Claridge': 2, 'Samuel Bownas': 1, 'John Whitehead': 1, 'Daniel Quare': 2, 'Silvanus Bevan': 1, 'Katharine Evans': 1, 'Sarah Cheevers': 1, 'John Whiting': 1, 'Christopher Taylor': 2, 'Alice Curwen': 1, 'Thomas Lawson': 2, 'Thomas Taylor': 1, 'John Penington': 1, 'Mary Penington': 4, 'Humphrey Woolrich': 1, 'Mary Pennyman': 1, 'Thomas Story': 1, 'Richard Vickris': 1, 'George Bishop': 1, 'Jane Sowle': 1, 'Elizabeth Leavens': 2, 'Lewis Morris': 1, 'Sir Charles Wager': 2, 'William Simpson': 1, 'Thomas Aldam': 1})

# %% [markdown]
# 1. Creation of different types of graphs:
#     - Undirected / Directed graphs
#     - Weighted / Unweighted graphs
#     - Bipartite graphs - how to project them onto one side
# 2. Plot degree distribution
# 3. Get the triadic closure - how to calculate clustering coefficient
# 4. Calculate communities?
# 5. Measure node importance:
#     - Degree centrality of node i = number of neighbours of node i
#     - Closeness centrality of node i = sum(1 / sum of distances from node i to other nodes)
#     - Betweenness centrality of node i = fraction of shortest pathes in the network that pass through node i
#     - Katz centrality - Generalization of Degree centrality
#     - PageRank centrality

# %% [markdown]
# ## Introducting Networkx

# %% [markdown]
# NetworkX has a broad range of example networks that you can load with just a function call ([more examples here](https://networkx.github.io/documentation/stable/auto_examples/index.html)).
#
# .. and a super friendly API that you can use to conviently build networks.
#
# In order to get used to NetworkX API, let's just construct a simple **undirected graph**

# %% [markdown]
# ### Creating and Visualizing a simple Undirected Graph

# %%
G = nx.Graph() # for a directed graph use nx.DiGraph()
# add nodes
G.add_node(1)
G.add_nodes_from(range(2,9))  # add multiple nodes at once

# add edges 
G.add_edge(1,2)
edges = [(2,3), (1,3), (4,1), (4,5), (5,6), (5,7), (6,7), (7,8), (6,8)]
G.add_edges_from(edges) # add multiple edges at once
print(G)
# Out:
# Graph with 8 nodes and 10 edges

# %% [markdown]
# Did you like to get a quick overview of your dataset using `.describe()` in pandas ?
# Here is the equivalent in NetworkX:

# %%
print(G)
# Out:
# Graph with 8 nodes and 10 edges

# %% [markdown]
# The library also has a built-in plotting engine (based on matplotlib).

# %%
# plot it out
# for different layouts, please see: https://networkx.github.io/documentation/stable/reference/drawing.html#module-networkx.drawing.layout
nx.draw_spring(G, with_labels=True,  alpha = 0.8)

# %%
# Helper function for plotting the degree distribution of a Graph
def plot_degree_distribution(G):
    degrees = {}
    for node in G.nodes():
        degree = G.degree(node)
        if degree not in degrees:
            degrees[degree] = 0
        degrees[degree] += 1
    sorted_degree = sorted(degrees.items())
    deg = [k for (k,v) in sorted_degree]
    cnt = [v for (k,v) in sorted_degree]
    fig, ax = plt.subplots()
    plt.bar(deg, cnt, width=0.80, color='b')
    plt.title("Degree Distribution")
    plt.ylabel("Frequency")
    plt.xlabel("Degree")
    ax.set_xticks([d+0.05 for d in deg])
    ax.set_xticklabels(deg)

# %%
# Helper function for printing various graph properties
def describe_graph(G):
    print(G)
    if nx.is_connected(G):
        print("Avg. Shortest Path Length: %.4f" %nx.average_shortest_path_length(G))
        print("Diameter: %.4f" %nx.diameter(G)) # Longest shortest path
    else:
        print("Graph is not connected")
        print("Diameter and Avg shortest path length are not defined!")
    print("Sparsity: %.4f" %nx.density(G))  # #edges/#edges-complete-graph
    # #closed-triplets(3*#triangles)/#all-triplets
    print("Global clustering coefficient aka Transitivity: %.4f" %nx.transitivity(G))

# %%
# Helper function for visualizing the graph
def visualize_graph(G, with_labels=True, k=None, alpha=1.0, node_shape='o'):
    #nx.draw_spring(G, with_labels=with_labels, alpha = alpha)
    pos = nx.spring_layout(G, k=k)
    if with_labels:
        lab = nx.draw_networkx_labels(G, pos, labels=dict([(n, n) for n in G.nodes()]))
    ec = nx.draw_networkx_edges(G, pos, alpha=alpha)
    nc = nx.draw_networkx_nodes(G, pos, nodelist=G.nodes(), node_color='g', node_shape=node_shape)
    plt.axis('off')

# %% [markdown]
# ### Creating and Visualizing an Erdős–Rényi graph

# %%
n = 10  # 10 nodes
m = 20  # 20 edges

erG = nx.gnm_random_graph(n, m)

describe_graph(erG)
visualize_graph(erG, k=0.05, alpha=0.8)
plot_degree_distribution(erG)
# Out:
# Graph with 10 nodes and 20 edges
# Avg. Shortest Path Length: 1.6000
# Diameter: 3.0000
# Sparsity: 0.4444
# Global clustering coefficient aka Transitivity: 0.4412

# %% [markdown]
# ### Creating and Visualizing the Zachary's Karate Club Network

# %%
karateG = nx.karate_club_graph()
describe_graph(karateG)
visualize_graph(karateG, k=0.05, alpha=0.8)
plot_degree_distribution(karateG)
# Out:
# Graph named "Zachary's Karate Club" with 34 nodes and 78 edges
# Avg. Shortest Path Length: 2.4082
# Diameter: 5.0000
# Sparsity: 0.1390
# Global clustering coefficient aka Transitivity: 0.2557

# %%
# Draw the graph with a circular layout instead?
nx.draw_circular(karateG, with_labels=True,  node_color='g', alpha = 0.8)

# %% [markdown]
# ## Section 2: Quakers !

# %% [markdown]
# Let's now go beyond toy examples and load real data!
#
# England, in the mid-17th century. A novel group of Protestant Christians, called "Religious Society of Friends" dissent from the main doctrine. Their members are known as the "Quakers". This dataset is derived from the ["Oxford Dictionary of National Biography"](http://www.oxforddnb.com/) and from the ongoing work of the *"Six Degrees of Francis Bacon project"*, which is reconstructing the social networks of early modern Britain (1500-1700) to trace the personal relationships among figures like **Bacon**, **Shakespeare**, **Sir Isaac Newton** and many others.
#
# [Credits](https://programminghistorian.org/en/lessons/exploring-and-analyzing-network-data-with-python)

# %% [markdown]
# ### Meet the Quakers

# %%
data_folder = './data/quakers/'
nodes = pd.read_csv(data_folder + 'quakers_nodelist.csv')
nodes.head(10)
# Out:
#                          Name           Historical Significance  Gender  \
# 0                Joseph Wyeth                  religious writer    male
# 1  Alexander Skene of Newtyle       local politician and author    male
# 2                 James Logan     colonial official and scholar    male
# 3               Dorcas Erbery                   Quaker preacher  female
# 4                Lilias Skene          Quaker preacher and poet    male
# 5             William Mucklow                  religious writer    male
# 6            Thomas Salthouse        Quaker preacher and writer    male
# 7            William Dewsbury                   Quaker activist    male
# 8                John Audland                   Quaker preacher    male
# 9            Richard Claridge  Quaker minister and schoolmaster    male
#
#    Birthdate  Deathdate        ID
# 0       1663       1731  10013191
# 1       1621       1694  10011149
# 2       1674       1751  10007567
# 3       1656       1659  10003983
# 4       1626       1697  10011152
# 5       1630       1713  10008595
# 6       1630       1691  10010643
# 7       1621       1688  10003478
# 8       1630       1664  10000411
# 9       1649       1723  10002469

# %%
nodes.Gender = nodes.Gender.astype('category')
nodes = nodes.rename({'Historical Significance': 'Role'}, axis = 1)
print('There are ', len(nodes), 'quakers')
# Out:
# There are  119 quakers

# %%
nodes['Role'].isna().sum()
# Out:
# 2

# %%
# some don't have a known 'historical significance' or 'role'
nodes['Role'].fillna('Unknown', inplace=True)

# %%
# check if the names are unique
nodes['Name'].nunique() == len(nodes)
# Out:
# True

# %%
# since the names are unique, index based on names
nodes.set_index('Name', inplace=True)

# let's also add a new attribute based on the role column. Is (s)he a directly involved Quaker or not? 
nodes['Quaker'] = ['quaker' in role.lower() for role in nodes.Role]
nodes.head()
# Out:
#                                                      Role  Gender  Birthdate  \
# Name
# Joseph Wyeth                             religious writer    male       1663
# Alexander Skene of Newtyle    local politician and author    male       1621
# James Logan                 colonial official and scholar    male       1674
# Dorcas Erbery                             Quaker preacher  female       1656
# Lilias Skene                     Quaker preacher and poet    male       1626
#
#                             Deathdate        ID  Quaker
# Name
# Joseph Wyeth                     1731  10013191   False
# Alexander Skene of Newtyle       1694  10011149   False
# James Logan                      1751  10007567   False
# Dorcas Erbery                    1659  10003983    True
# Lilias Skene                     1697  10011152    True

# %%
# let's see which quaker knows whom, this will translate into edges in our graph
edges = pd.read_csv(data_folder + 'quakers_edgelist.csv')
edges.head()
# Out:
#          Source                                         Target
# 0  George Keith                                 Robert Barclay
# 1  George Keith                                 Benjamin Furly
# 2  George Keith  Anne Conway Viscountess Conway and Killultagh
# 3  George Keith               Franciscus Mercurius van Helmont
# 4  George Keith                                   William Penn

# %%
print('There are',len(edges), 'edges')
# Out:
# There are 174 edges

# %% [markdown]
# ### The Quaker network

# %% [markdown]
# Now we have all the ingredients and more to translate this data into a network: nodes are the quakers and there exists an edge between two quakers if they know each other. Since being acquainted or friends is a symmetric relation, we will build an undirected graph.
#
# Another bonus of NetworkX is the smooth integration with panda dataframes, which makes loading the network a one-liner.
# *Note: Only if you don't have isolated nodes*

# %%
quakerG = nx.from_pandas_edgelist(edges, 'Source', 'Target', edge_attr=None, create_using= nx.Graph())
describe_graph(quakerG)
# Out:
# Graph with 119 nodes and 174 edges
# Graph is not connected
# Diameter and Avg shortest path length are not defined!
# Sparsity: 0.0248
# Global clustering coefficient aka Transitivity: 0.1694

# %%
# add node attributes by passing dictionary of type name -> attribute
nx.set_node_attributes(quakerG, nodes['Role'].to_dict(), 'Role' )
nx.set_node_attributes(quakerG, nodes['Gender'].to_dict(), 'Gender' )
nx.set_node_attributes(quakerG, nodes['Birthdate'].to_dict(), 'Birthdate' )
nx.set_node_attributes(quakerG, nodes['Deathdate'].to_dict(), 'Deathdate' )
nx.set_node_attributes(quakerG, nodes['Quaker'].to_dict(), 'Quaker' )

# %%
# You can easily get the attributes of a node
quakerG.nodes['William Penn']
# Out:
# {'Role': 'Quaker leader and founder of Pennsylvania',
#  'Gender': 'male',
#  'Birthdate': 1644,
#  'Deathdate': 1718,
#  'Quaker': True}

# %% [markdown]
# ### How connected is the quaker network ?

# %% [markdown]
# To get a feel of the network, we could start by visually inspecting the graph.

# %%
nx.draw_spring(quakerG, node_shape='.')

# %%
visualize_graph(quakerG, False, k=0.05, alpha=0.4)

# %% [markdown]
# Let's try to make the visualization a bit better...

# %%
visualize_graph(quakerG, False, k=0.2, alpha=0.4, node_shape='.')

# %% [markdown]
# Still not a very pretty visualisation (.. install  [Gephy](https://gephi.org/) for some better-looking plots). However, a few things come across:
#
# * The graph is not connected (there are a few isolated communities)
# * There seem to be a few nodes with many connections (i.e. hubs)
#
# That's as far as we can get, let's revert to **numbers and graph properties** for more insights!

# %% [markdown]
# ### Sparsity
# "Sparsity" of a graph with $n$ nodes is defined as follows:
#
# $ L = \frac{|E|}{|E_{max}|}$, where $E_{max} = \frac{n * (n-1)}{2}$

# %%
# 174 * (2) / ( 119* 118)
print("Network sparsity: %.4f" %nx.density(quakerG))
# Out:
# Network sparsity: 0.0248

# %% [markdown]
# ### Connected Components
# If the graph is not connected, how many "connected components" are there ?

# %%
print(nx.is_connected(quakerG))
comp = list(nx.connected_components(quakerG))
print('The graph contains', len(comp), 'connected components')
# Out:
# False
# The graph contains 12 connected components

# %%
largest_comp = max(comp, key=len)
percentage_lcc = len(largest_comp)/quakerG.number_of_nodes() * 100
print('The largest component has', len(largest_comp), 'nodes', 'accounting for %.2f'% percentage_lcc, '% of the nodes')
# Out:
# The largest component has 96 nodes accounting for 80.67 % of the nodes

# %% [markdown]
# From visually inspecting the graph, we already saw that most of the nodes are in the largest component, which is often the case in a graph. That is why we usually call this component as a **giant component**.

# %% [markdown]
# ### Diameter and Shortest Paths
# Suppose I want to find the shortest path between two quakers, given that they are in the same connected component

# %%
fell_whitehead_path = nx.shortest_path(quakerG, source="Margaret Fell", target="George Whitehead")
print("Shortest path between Fell and Whitehead:", fell_whitehead_path)
# Out:
# Shortest path between Fell and Whitehead: ['Margaret Fell', 'George Fox', 'George Whitehead']

# %%
# take the largest component and analyse its diameter = longest shortest-path
lcc_quakerG = quakerG.subgraph(largest_comp)
print("The diameter of the largest connected component is", nx.diameter(lcc_quakerG))
print("The avg shortest path length of the largest connected component is", nx.average_shortest_path_length(lcc_quakerG))
# Out:
# The diameter of the largest connected component is 8
# The avg shortest path length of the largest connected component is 3.3789473684210525

# %% [markdown]
# ### A more social look at the network!
#
# **Triadic Closure:**
#     A *friend* of my *friend* is my *friend*
#     OR
#     *quaker_1* knows *quaker_2* and *quaker_2* knows *quaker_3*, how likely is that *quaker_1* and *quaker_3* know each other?
#
# Employ a **global** measure called **transitivity** (aka global clustering coefficient), or the ratio of all existing triangles (closed triples) over all possible triangles (open and closed triplets).

# %%
print('%.4f' %nx.transitivity(quakerG))
# Out:
# 0.1694

# %% [markdown]
# Employ a **local** measure called **clustering coefficient**, which quantifies for a node how close its neighbours are to being a clique (complete graph). Measured as the ratio of, the number of edges to the number of all possible edges, among the neighbors of a node.

# %%
# Similar measure but for individual nodes called clustering coefficient
print(nx.clustering(quakerG, ['Alexander Parker']))
# Out:
# {'Alexander Parker': 0.06666666666666667}

# %%
list(nx.neighbors(quakerG,'Alexander Parker'))
# Out:
# ['John Wilkinson',
#  'Benjamin Furly',
#  'George Whitehead',
#  'Thomas Lawson',
#  'Margaret Fell',
#  'Sir Charles Wager']

# %%
list(quakerG.neighbors('Alexander Parker'))
# Out:
# ['John Wilkinson',
#  'Benjamin Furly',
#  'George Whitehead',
#  'Thomas Lawson',
#  'Margaret Fell',
#  'Sir Charles Wager']

# %%
# Lets check by looking at the subgraphs induced by Alex and John
subgraph_Alex = quakerG.subgraph(['Alexander Parker']+list(quakerG.neighbors('Alexander Parker')))
subgraph_John = quakerG.subgraph(['John Crook']+list(quakerG.neighbors('John Crook')))

# %%
nx.draw_spring(subgraph_Alex, with_labels=True)

# %%
nx.draw_circular(subgraph_John, with_labels=True)

# %% [markdown]
# ### Which quakers are the most important ?
#
# As always, the answer is ... it depends. There are many ways to detect important nodes in a graph, for example based on:
#
# * **Degree** (generalized by **Katz**)
# * **Betweeness centrality**
# * More ...

# %% [markdown]
# #### Degree: the more people you know, the more important you are!

# %%
degrees = dict(quakerG.degree(quakerG.nodes()))
sorted_degree = sorted(degrees.items(), key=itemgetter(1), reverse=True)

# And the top 5 most popular quakers are.. 
for quaker, degree in sorted_degree[:5]:
    print(quaker, 'who is', quakerG.nodes[quaker]['Role'], 'knows', degree, 'people')
# Out:
# George Fox who is  a founder of the Religious Society of Friends (Quakers) knows 22 people
# William Penn who is Quaker leader and founder of Pennsylvania knows 18 people
# James Nayler who is Quaker preacher and writer knows 16 people
# George Whitehead who is Quaker leader and writer knows 13 people
# Margaret Fell who is Quaker leader knows 13 people

# %% [markdown]
# Let's also analyze the *degree distribution*.
# We can see that most of the people know less than 5 quakers and there are some *leaders that are comparatively very popular*.

# %%
degree_seq = [d[1] for d in sorted_degree]
degreeCount = collections.Counter(degree_seq)
degreeCount = pd.DataFrame.from_dict( degreeCount, orient='index').reset_index()
fig = plt.figure()
ax = plt.gca()
ax.plot(degreeCount['index'], degreeCount[0], 'o', c='blue', markersize= 4)
plt.ylabel('Frequency')
plt.xlabel('Degree')
plt.title('Degree distribution for the Quaker network')
# Out:
# Text(0.5, 1.0, 'Degree distribution for the Quaker network')

# %%
# As a bar plot
plot_degree_distribution(quakerG)

# %% [markdown]
# #### What about the Katz Centrality (the generalization over degree centrality)?

# %%
betweeness = nx.betweenness_centrality(quakerG)
nx.set_node_attributes(quakerG, betweeness, 'betweeness')
quakerG.nodes['George Fox']
# Out:
# {'Role': ' a founder of the Religious Society of Friends (Quakers)',
#  'Gender': 'male',
#  'Birthdate': 1624,
#  'Deathdate': 1691,
#  'Quaker': True,
#  'katz': 0.3419514541276866,
#  'betweeness': 0.23683257726065213}

# %%
degrees = dict(quakerG.degree(quakerG.nodes()))

katz = nx.katz_centrality(quakerG)
nx.set_node_attributes(quakerG, katz, 'katz')
sorted_katz = sorted(katz.items(), key=itemgetter(1), reverse=True)

# And the top 5 most popular quakers are.. 
for quaker, katzc in sorted_katz[:5]:
    print(quaker, 'who is', quakerG.nodes[quaker]['Role'], 'has katz-centrality: %.3f' %katzc)
# Out:
# George Fox who is  a founder of the Religious Society of Friends (Quakers) has katz-centrality: 0.342
# James Nayler who is Quaker preacher and writer has katz-centrality: 0.261
# William Penn who is Quaker leader and founder of Pennsylvania has katz-centrality: 0.249
# George Whitehead who is Quaker leader and writer has katz-centrality: 0.216
# Margaret Fell who is Quaker leader has katz-centrality: 0.215

# %% [markdown]
# Note: this is an undirected graph. If you were to have a **directed** one, use separate metrics for **indegree** and **outdegree**.

# %% [markdown]
# #### Betweeness centrality: the more shortest paths pass through a node, the more important it is!

# %%
# Compute betweenness centrality
betweenness = nx.betweenness_centrality(quakerG)
# Assign the computed centrality values as a node-attribute in your network
nx.set_node_attributes(quakerG, betweenness, 'betweenness')
sorted_betweenness = sorted(betweenness.items(), key=itemgetter(1), reverse=True)

for quaker, bw in sorted_betweenness[:5]:
    print(quaker, 'who is', quakerG.nodes[quaker]['Role'], 'has betweeness: %.3f' %bw)
# Out:
# William Penn who is Quaker leader and founder of Pennsylvania has betweeness: 0.240
# George Fox who is  a founder of the Religious Society of Friends (Quakers) has betweeness: 0.237
# George Whitehead who is Quaker leader and writer has betweeness: 0.126
# Margaret Fell who is Quaker leader has betweeness: 0.121
# James Nayler who is Quaker preacher and writer has betweeness: 0.104

# %% [markdown]
# Let's analyze the betweeness centrality values for all the nodes in the network. As in the case with degree, there are a *few nodes with very high betweeness centrality*, while most of them have a low value.

# %%
# similar pattern
list_nodes =list(quakerG.nodes())
list_nodes.reverse()   # for showing the nodes with high betweeness centrality 
pos = nx.spring_layout(quakerG)
ec = nx.draw_networkx_edges(quakerG, pos, alpha=0.1)
nc = nx.draw_networkx_nodes(quakerG, pos, nodelist=list_nodes, node_color=[quakerG.nodes[n]["betweenness"] for n in list_nodes], 
                            alpha=0.8, node_shape = '.')
plt.colorbar(nc)
plt.axis('off')
plt.show()

# %% [markdown]
# At this point you might be tempted to think the measures are very similar, but let's revisit the original graph (G)

# %%
nx.set_node_attributes(G, nx.betweenness_centrality(G), 'betweenness')
pos = nx.spring_layout(G)
ec = nx.draw_networkx(G, pos, nodelist=G.nodes(),
                         node_color=[G.nodes[n]["betweenness"] for n in G.nodes()], 
                         node_shape = '.', node_size=1200, font_color="white", font_weight="bold")
plt.colorbar(nc)
plt.axis('off')
plt.show()

# %% [markdown]
# The node with the **lowest degree** is the one with the **highest betweeness centrality**.
#
# This concept also translates to edges. In particular, edge betweeness is the number of shortest paths that pass through an edge. This brings us to ...

# %% [markdown]
# ### The quaker communities
#
# Community detection is a common class of methods applied to graphs.
# Two important algorithms:
# * **Girvan Newman**
# * **Louvain**

# %% [markdown]
# #### Girvan Newman
# **Idea:** Edges possessing high betweeness centrality separate communities. Let's apply this on our toy sample graph (G) to get a better understanding of the idea.
#
# The algorithm starts with the entire graph and then it iteratively removes the edge with the highest betweeness.

# %%
comp = girvan_newman(G)
it = 0
for communities in itertools.islice(comp, 10):
    it +=1
    print('Iteration', it)
    print(tuple(sorted(c) for c in communities))
# Out:
# Iteration 1
# ([1, 2, 3, 4], [5, 6, 7, 8])
# Iteration 2
# ([1, 2, 3], [4], [5, 6, 7, 8])
# Iteration 3
# ([1, 2, 3], [4], [5], [6, 7, 8])
# Iteration 4
# ([1], [2, 3], [4], [5], [6, 7, 8])
# Iteration 5
# ([1], [2], [3], [4], [5], [6, 7, 8])
# Iteration 6
# ([1], [2], [3], [4], [5], [6], [7, 8])
# Iteration 7
# ([1], [2], [3], [4], [5], [6], [7], [8])

# %%
visualize_graph(G,alpha=0.7)

# %% [markdown]
# #### The [Louvain method](https://en.wikipedia.org/wiki/Louvain_Modularity)
#
# Another clustering algorithm and has become a standard algorithm in the data scientist toolbox.
# **Idea:** It proceeds the other way around: initially every node is considered as a community. The communities are traversed, and for each community it is tested whether by joining it to a neighboring community, we can obtain a better clustering.

# %%
partition['James Nayler']
# Out:
# 10

# %%
cluster_James = partition['James Nayler']
# Take all the nodes that belong to James' cluster
members_c = [q for q in quakerG.nodes if partition[q] == cluster_James]
# get info about these quakers
for quaker in members_c:
    print(quaker, 'who is', quakerG.nodes[quaker]['Role'], 'and died in ',quakerG.nodes[quaker]['Deathdate'])

# %%
partition = community_louvain.best_partition(quakerG)
# add it as an attribute to the nodes
for n in quakerG.nodes:
    quakerG.nodes[n]["louvain"] = partition[n]

# %%
# plot it out
pos = nx.spring_layout(quakerG,k=0.2)
ec = nx.draw_networkx_edges(quakerG, pos, alpha=0.2)
nc = nx.draw_networkx_nodes(quakerG, pos, nodelist=quakerG.nodes(), node_color=[quakerG.nodes[n]["louvain"] for n in quakerG.nodes], 
                            node_size=100, cmap=plt.cm.jet)
plt.axis('off')
plt.show()

# %% [markdown]
# Let's get a closer look at a few clusters and show their member's role and period in which they lived

# %%
cluster_James = partition['James Nayler']
# Take all the nodes that belong to James' cluster
members_c = [q for q in quakerG.nodes if partition[q] == cluster_James]
# get info about these quakers
for quaker in members_c:
    print(quaker, 'who is', quakerG.nodes[quaker]['Role'], 'and died in ',quakerG.nodes[quaker]['Deathdate'])
# Out:
# Dorcas Erbery who is Quaker preacher and died in  1659
# James Nayler who is Quaker preacher and writer and died in  1660
# Francis Howgill who is Quaker activist and died in  1669
# Martha Simmonds who is Quaker and author and died in  1665
# Richard Farnworth who is Quaker preacher and writer and died in  1666
# William Crouch who is Quaker leader and writer and died in  1711
# Hannah Stranger who is Quaker missionary and died in  1671
# Gervase Benson who is Quaker leader and died in  1679
# Robert Rich who is Quaker adherent and sectary and died in  1679
# Anthony Pearson who is Quaker administrator and died in  1666
# William Tomlinson who is religious writer and died in  1696
# Richard Hubberthorne who is Quaker activist and died in  1662
# Thomas Aldam who is Quaker preacher and writer and died in  1660

# %%
cluster_Lydia = partition['Lydia Lancaster']
# Take all the nodes that belong to Lydia's cluster
members_c = [q for q in quakerG.nodes if partition[q] == cluster_Lydia]
# get info about these quakers
for quaker in members_c:
    print(quaker, 'who is', quakerG.nodes[quaker]['Role'], 'and died in ',quakerG.nodes[quaker]['Deathdate'])
# Out:
# Lydia Lancaster who is Quaker minister and died in  1761
# Grace Chamber who is Quaker minister and died in  1762

# %% [markdown]
# ### Homophily in quakers
# How likely is it that two quakers who have the same attribute are linked?
#
# Try to measure the similarity of connections in the graph with respect to a given attribute.
# *Intuition: Like correlation, but translated to graphs.*

# %%
# for categorical attributes
nx.attribute_assortativity_coefficient(quakerG, 'Gender')
# Out:
# 0.1882377889305155

# %%
nodes.groupby('Gender').size()
# Out:
# Gender
# female    22
# male      97
# dtype: int64

# %% [markdown]
# There is no notion of *gender homophily* in this network, which makes sense due to the following:
# * Couples
# * Gender imbalance

# %% [markdown]
# However, there exists **age homophily**: quakers that died in the same period are more likely to be linked

# %%
# for numerical attributes, values must be integers
nx.numeric_assortativity_coefficient(quakerG, 'Deathdate')
# Out:
# 0.5841284189309789

# %% [markdown]
# ### Few Exercises
# 1. Visually determine the diameter of the small graph we built at the beginning (G) and then check you got it right.
# 2. Experiment with the Girvan Newman algorithm on the Quaker (quakerG) network.
# 3. Compute role homophily in the Quaker network.
# *Hint: You can either do it based on the given roles you have or develop a more coarse categorisation of roles and repeat your analysis after.*

# %% [markdown]
# ### 1

# %%
nx.draw(G)  # d=5
nx.diameter(G)
# Out:
# 5

# %% [markdown]
# ### 2

# %%
visualize_graph(quakerG, with_labels=False, alpha=0.5, node_shape='.')

# %%
comp = girvan_newman(quakerG)
it = 0
for communities in itertools.islice(comp, 20):
    it +=1
    print('Iteration', it)
    print(tuple(sorted(c) for c in communities))
    pos = nx.spring_layout(quakerG,k=0.2)
    ec = nx.draw_networkx_edges(quakerG, pos=pos, alpha=0.2)
    nc = nx.draw_networkx_nodes(quakerG, pos, nodelist=quakerG.nodes(), node_color=[i + 1 for i, s in enumerate(communities) for element in s], 
                                node_size=100, cmap=plt.cm.jet)
    plt.axis('off')
    plt.show()
# Out:
# Iteration 1
# (['Alexander Parker', 'Alice Curwen', 'Anne Camm', 'Anne Conway Viscountess Conway and Killultagh', 'Anthony Pearson', 'Benjamin Furly', 'Charles Marshall', 'Daniel Quare', 'David Barclay of Ury', 'Dorcas Erbery', 'Edward Burrough', 'Edward Pyott', 'Elizabeth Hooten', 'Elizabeth Leavens', 'Ellis Hookes', 'Francis Bugg', 'Francis Howgill', 'Franciscus Mercurius van Helmont', 'George Fox', 'George Fox the younger', 'George Keith', 'George Whitehead', 'Gervase Benson', 'Gilbert Latey', 'Hannah Stranger', 'Henry Pickworth', 'James Nayler', 'James Parnel', 'John Audland', 'John Camm', 'John Crook', 'John Penington', 'John Perrot', 'John Story', 'John Stubbs', 'John Swinton', 'John Whitehead', 'John Wilkinson', 'Joseph Wyeth', 'Leonard Fell', 'Lewis Morris', 'Margaret Fell', 'Martha Simmonds', 'Mary Fisher', 'Mary Penington', 'Mary Prince', 'Rebecca Travers', 'Richard Farnworth', 'Richard Hubberthorne', 'Robert Barclay', 'Robert Rich', 'Samuel Fisher', 'Silvanus Bevan', 'Sir Charles Wager', 'Solomon Eccles', 'Stephen Crisp', 'Thomas Aldam', 'Thomas Camm', 'Thomas Curtis', 'Thomas Ellwood', 'Thomas Holme', 'Thomas Lawson', 'Thomas Lower', 'Thomas Salthouse', 'William Ames', 'William Caton', 'William Coddington', 'William Crouch', 'William Dewsbury', 'William Gibson', 'William Mead', 'William Mucklow', 'William Rogers', 'William Simpson', 'William Tomlinson'], ['Anthony Sharp', 'David Lloyd', 'Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'James Claypoole', 'James Logan', 'Jane Sowle', 'John Bartram', 'John Burnyeat', 'John ap John', 'Joseph Besse', 'Peter Collinson', 'Richard Claridge', 'Samuel Bownas', 'Samuel Clarridge', 'Tace Sowle', 'Thomas Story', 'William Bradford', 'William Edmundson', 'William Penn'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Fettiplace Bellers', 'John Bellers'], ['Grace Chamber', 'Lydia Lancaster'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Gideon Wanton', 'John Wanton'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])
# Iteration 2
# (['Anne Conway Viscountess Conway and Killultagh', 'Benjamin Furly', 'David Barclay of Ury', 'Franciscus Mercurius van Helmont', 'George Keith', 'James Parnel', 'John Stubbs', 'John Swinton', 'Robert Barclay', 'Samuel Fisher', 'Stephen Crisp', 'William Ames', 'William Caton'], ['Anthony Sharp', 'David Lloyd', 'Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'James Claypoole', 'James Logan', 'Jane Sowle', 'John Bartram', 'John Burnyeat', 'John ap John', 'Joseph Besse', 'Peter Collinson', 'Richard Claridge', 'Samuel Bownas', 'Samuel Clarridge', 'Tace Sowle', 'Thomas Story', 'William Bradford', 'William Edmundson', 'William Penn'], ['Alexander Parker', 'Alice Curwen', 'Anne Camm', 'Anthony Pearson', 'Charles Marshall', 'Daniel Quare', 'Dorcas Erbery', 'Edward Burrough', 'Edward Pyott', 'Elizabeth Hooten', 'Elizabeth Leavens', 'Ellis Hookes', 'Francis Bugg', 'Francis Howgill', 'George Fox', 'George Fox the younger', 'George Whitehead', 'Gervase Benson', 'Gilbert Latey', 'Hannah Stranger', 'Henry Pickworth', 'James Nayler', 'John Audland', 'John Camm', 'John Crook', 'John Penington', 'John Perrot', 'John Story', 'John Whitehead', 'John Wilkinson', 'Joseph Wyeth', 'Leonard Fell', 'Lewis Morris', 'Margaret Fell', 'Martha Simmonds', 'Mary Fisher', 'Mary Penington', 'Mary Prince', 'Rebecca Travers', 'Richard Farnworth', 'Richard Hubberthorne', 'Robert Rich', 'Silvanus Bevan', 'Sir Charles Wager', 'Solomon Eccles', 'Thomas Aldam', 'Thomas Camm', 'Thomas Curtis', 'Thomas Ellwood', 'Thomas Holme', 'Thomas Lawson', 'Thomas Lower', 'Thomas Salthouse', 'William Coddington', 'William Crouch', 'William Dewsbury', 'William Gibson', 'William Mead', 'William Mucklow', 'William Rogers', 'William Simpson', 'William Tomlinson'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Fettiplace Bellers', 'John Bellers'], ['Grace Chamber', 'Lydia Lancaster'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Gideon Wanton', 'John Wanton'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])
# Iteration 3
# (['Anne Conway Viscountess Conway and Killultagh', 'Benjamin Furly', 'David Barclay of Ury', 'Franciscus Mercurius van Helmont', 'George Keith', 'James Parnel', 'John Stubbs', 'John Swinton', 'Robert Barclay', 'Samuel Fisher', 'Stephen Crisp', 'William Ames', 'William Caton'], ['Anthony Sharp', 'David Lloyd', 'Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'James Claypoole', 'James Logan', 'Jane Sowle', 'John Bartram', 'John Burnyeat', 'John ap John', 'Joseph Besse', 'Peter Collinson', 'Richard Claridge', 'Samuel Bownas', 'Samuel Clarridge', 'Tace Sowle', 'Thomas Story', 'William Bradford', 'William Edmundson', 'William Penn'], ['Alexander Parker', 'Alice Curwen', 'Anne Camm', 'Anthony Pearson', 'Charles Marshall', 'Daniel Quare', 'Dorcas Erbery', 'Edward Burrough', 'Edward Pyott', 'Elizabeth Hooten', 'Ellis Hookes', 'Francis Bugg', 'Francis Howgill', 'George Fox', 'George Fox the younger', 'George Whitehead', 'Gervase Benson', 'Gilbert Latey', 'Hannah Stranger', 'Henry Pickworth', 'James Nayler', 'John Audland', 'John Camm', 'John Crook', 'John Penington', 'John Perrot', 'John Story', 'John Whitehead', 'John Wilkinson', 'Joseph Wyeth', 'Leonard Fell', 'Lewis Morris', 'Margaret Fell', 'Martha Simmonds', 'Mary Fisher', 'Mary Penington', 'Mary Prince', 'Rebecca Travers', 'Richard Farnworth', 'Richard Hubberthorne', 'Robert Rich', 'Silvanus Bevan', 'Sir Charles Wager', 'Solomon Eccles', 'Thomas Aldam', 'Thomas Camm', 'Thomas Curtis', 'Thomas Ellwood', 'Thomas Lawson', 'Thomas Lower', 'Thomas Salthouse', 'William Coddington', 'William Crouch', 'William Dewsbury', 'William Mead', 'William Mucklow', 'William Rogers', 'William Simpson', 'William Tomlinson'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Fettiplace Bellers', 'John Bellers'], ['Grace Chamber', 'Lydia Lancaster'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Elizabeth Leavens', 'Thomas Holme', 'William Gibson'], ['Gideon Wanton', 'John Wanton'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])
# Iteration 4
# (['Anne Conway Viscountess Conway and Killultagh', 'Benjamin Furly', 'David Barclay of Ury', 'Franciscus Mercurius van Helmont', 'George Keith', 'James Parnel', 'John Stubbs', 'John Swinton', 'Robert Barclay', 'Samuel Fisher', 'Stephen Crisp', 'William Ames', 'William Caton'], ['Anthony Sharp', 'David Lloyd', 'Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'James Claypoole', 'James Logan', 'Jane Sowle', 'John Bartram', 'John Burnyeat', 'John ap John', 'Joseph Besse', 'Peter Collinson', 'Richard Claridge', 'Samuel Bownas', 'Samuel Clarridge', 'Tace Sowle', 'Thomas Story', 'William Bradford', 'William Edmundson', 'William Penn'], ['Anne Camm', 'Anthony Pearson', 'Charles Marshall', 'Dorcas Erbery', 'Edward Burrough', 'Edward Pyott', 'Elizabeth Hooten', 'Ellis Hookes', 'Francis Howgill', 'George Fox', 'George Fox the younger', 'Gervase Benson', 'Hannah Stranger', 'James Nayler', 'John Audland', 'John Camm', 'John Crook', 'John Penington', 'John Perrot', 'John Story', 'John Wilkinson', 'Joseph Wyeth', 'Leonard Fell', 'Margaret Fell', 'Martha Simmonds', 'Mary Fisher', 'Mary Penington', 'Mary Prince', 'Richard Farnworth', 'Robert Rich', 'Solomon Eccles', 'Thomas Aldam', 'Thomas Camm', 'Thomas Curtis', 'Thomas Ellwood', 'Thomas Lower', 'Thomas Salthouse', 'William Coddington', 'William Crouch', 'William Dewsbury', 'William Mead', 'William Mucklow', 'William Simpson', 'William Tomlinson'], ['Alexander Parker', 'Alice Curwen', 'Daniel Quare', 'Francis Bugg', 'George Whitehead', 'Gilbert Latey', 'Henry Pickworth', 'John Whitehead', 'Lewis Morris', 'Rebecca Travers', 'Richard Hubberthorne', 'Silvanus Bevan', 'Sir Charles Wager', 'Thomas Lawson', 'William Rogers'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Fettiplace Bellers', 'John Bellers'], ['Grace Chamber', 'Lydia Lancaster'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Elizabeth Leavens', 'Thomas Holme', 'William Gibson'], ['Gideon Wanton', 'John Wanton'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])
# Iteration 5
# (['Anne Conway Viscountess Conway and Killultagh', 'Benjamin Furly', 'David Barclay of Ury', 'Franciscus Mercurius van Helmont', 'George Keith', 'James Parnel', 'John Stubbs', 'John Swinton', 'Robert Barclay', 'Samuel Fisher', 'Stephen Crisp', 'William Ames', 'William Caton'], ['Anthony Sharp', 'David Lloyd', 'Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'James Claypoole', 'James Logan', 'Jane Sowle', 'John Bartram', 'John Burnyeat', 'John ap John', 'Joseph Besse', 'Peter Collinson', 'Richard Claridge', 'Samuel Bownas', 'Samuel Clarridge', 'Tace Sowle', 'Thomas Story', 'William Bradford', 'William Edmundson', 'William Penn'], ['Anthony Pearson', 'Dorcas Erbery', 'Edward Burrough', 'Elizabeth Hooten', 'Ellis Hookes', 'Francis Howgill', 'George Fox', 'George Fox the younger', 'Gervase Benson', 'Hannah Stranger', 'James Nayler', 'John Crook', 'John Perrot', 'Joseph Wyeth', 'Leonard Fell', 'Margaret Fell', 'Martha Simmonds', 'Mary Fisher', 'Mary Prince', 'Richard Farnworth', 'Robert Rich', 'Thomas Aldam', 'Thomas Ellwood', 'Thomas Lower', 'Thomas Salthouse', 'William Coddington', 'William Crouch', 'William Dewsbury', 'William Mead', 'William Mucklow', 'William Tomlinson'], ['Alexander Parker', 'Alice Curwen', 'Daniel Quare', 'Francis Bugg', 'George Whitehead', 'Gilbert Latey', 'Henry Pickworth', 'John Whitehead', 'Lewis Morris', 'Rebecca Travers', 'Richard Hubberthorne', 'Silvanus Bevan', 'Sir Charles Wager', 'Thomas Lawson', 'William Rogers'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Anne Camm', 'Charles Marshall', 'Edward Pyott', 'John Audland', 'John Camm', 'John Penington', 'John Story', 'John Wilkinson', 'Mary Penington', 'Solomon Eccles', 'Thomas Camm', 'Thomas Curtis', 'William Simpson'], ['Fettiplace Bellers', 'John Bellers'], ['Grace Chamber', 'Lydia Lancaster'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Elizabeth Leavens', 'Thomas Holme', 'William Gibson'], ['Gideon Wanton', 'John Wanton'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])
# Iteration 6
# (['Anne Conway Viscountess Conway and Killultagh', 'Benjamin Furly', 'David Barclay of Ury', 'Franciscus Mercurius van Helmont', 'George Keith', 'James Parnel', 'John Stubbs', 'John Swinton', 'Robert Barclay', 'Samuel Fisher', 'Stephen Crisp', 'William Ames', 'William Caton'], ['David Lloyd', 'Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'James Logan', 'Jane Sowle', 'John Bartram', 'Joseph Besse', 'Peter Collinson', 'Richard Claridge', 'Samuel Bownas', 'Tace Sowle', 'Thomas Story', 'William Bradford', 'William Penn'], ['Anthony Pearson', 'Dorcas Erbery', 'Edward Burrough', 'Elizabeth Hooten', 'Ellis Hookes', 'Francis Howgill', 'George Fox', 'George Fox the younger', 'Gervase Benson', 'Hannah Stranger', 'James Nayler', 'John Crook', 'John Perrot', 'Joseph Wyeth', 'Leonard Fell', 'Margaret Fell', 'Martha Simmonds', 'Mary Fisher', 'Mary Prince', 'Richard Farnworth', 'Robert Rich', 'Thomas Aldam', 'Thomas Ellwood', 'Thomas Lower', 'Thomas Salthouse', 'William Coddington', 'William Crouch', 'William Dewsbury', 'William Mead', 'William Mucklow', 'William Tomlinson'], ['Alexander Parker', 'Alice Curwen', 'Daniel Quare', 'Francis Bugg', 'George Whitehead', 'Gilbert Latey', 'Henry Pickworth', 'John Whitehead', 'Lewis Morris', 'Rebecca Travers', 'Richard Hubberthorne', 'Silvanus Bevan', 'Sir Charles Wager', 'Thomas Lawson', 'William Rogers'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Anne Camm', 'Charles Marshall', 'Edward Pyott', 'John Audland', 'John Camm', 'John Penington', 'John Story', 'John Wilkinson', 'Mary Penington', 'Solomon Eccles', 'Thomas Camm', 'Thomas Curtis', 'William Simpson'], ['Fettiplace Bellers', 'John Bellers'], ['Anthony Sharp', 'James Claypoole', 'John Burnyeat', 'John ap John', 'Samuel Clarridge', 'William Edmundson'], ['Grace Chamber', 'Lydia Lancaster'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Elizabeth Leavens', 'Thomas Holme', 'William Gibson'], ['Gideon Wanton', 'John Wanton'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])
# Iteration 7
# (['Anne Conway Viscountess Conway and Killultagh', 'Benjamin Furly', 'David Barclay of Ury', 'Franciscus Mercurius van Helmont', 'George Keith', 'James Parnel', 'John Stubbs', 'John Swinton', 'Robert Barclay', 'Samuel Fisher', 'Stephen Crisp', 'William Ames', 'William Caton'], ['David Lloyd', 'Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'James Logan', 'Jane Sowle', 'John Bartram', 'Joseph Besse', 'Peter Collinson', 'Richard Claridge', 'Samuel Bownas', 'Tace Sowle', 'Thomas Story', 'William Bradford', 'William Penn'], ['Elizabeth Hooten', 'Ellis Hookes', 'George Fox', 'George Fox the younger', 'Leonard Fell', 'Margaret Fell', 'Thomas Lower', 'Thomas Salthouse', 'William Coddington', 'William Mead', 'William Mucklow'], ['Alexander Parker', 'Alice Curwen', 'Daniel Quare', 'Francis Bugg', 'George Whitehead', 'Gilbert Latey', 'Henry Pickworth', 'John Whitehead', 'Lewis Morris', 'Rebecca Travers', 'Richard Hubberthorne', 'Silvanus Bevan', 'Sir Charles Wager', 'Thomas Lawson', 'William Rogers'], ['Anthony Pearson', 'Dorcas Erbery', 'Edward Burrough', 'Francis Howgill', 'Gervase Benson', 'Hannah Stranger', 'James Nayler', 'John Crook', 'John Perrot', 'Joseph Wyeth', 'Martha Simmonds', 'Mary Fisher', 'Mary Prince', 'Richard Farnworth', 'Robert Rich', 'Thomas Aldam', 'Thomas Ellwood', 'William Crouch', 'William Dewsbury', 'William Tomlinson'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Anne Camm', 'Charles Marshall', 'Edward Pyott', 'John Audland', 'John Camm', 'John Penington', 'John Story', 'John Wilkinson', 'Mary Penington', 'Solomon Eccles', 'Thomas Camm', 'Thomas Curtis', 'William Simpson'], ['Fettiplace Bellers', 'John Bellers'], ['Anthony Sharp', 'James Claypoole', 'John Burnyeat', 'John ap John', 'Samuel Clarridge', 'William Edmundson'], ['Grace Chamber', 'Lydia Lancaster'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Elizabeth Leavens', 'Thomas Holme', 'William Gibson'], ['Gideon Wanton', 'John Wanton'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])
# Iteration 8
# (['Anne Conway Viscountess Conway and Killultagh', 'Benjamin Furly', 'David Barclay of Ury', 'Franciscus Mercurius van Helmont', 'George Keith', 'James Parnel', 'John Stubbs', 'John Swinton', 'Robert Barclay', 'Samuel Fisher', 'Stephen Crisp', 'William Ames', 'William Caton'], ['David Lloyd', 'Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'James Logan', 'Jane Sowle', 'John Bartram', 'Joseph Besse', 'Peter Collinson', 'Richard Claridge', 'Samuel Bownas', 'Tace Sowle', 'Thomas Story', 'William Bradford', 'William Penn'], ['Elizabeth Hooten', 'Ellis Hookes', 'George Fox', 'George Fox the younger', 'Leonard Fell', 'Margaret Fell', 'Thomas Lower', 'Thomas Salthouse', 'William Coddington', 'William Mead', 'William Mucklow'], ['Alice Curwen', 'Daniel Quare', 'Francis Bugg', 'George Whitehead', 'Gilbert Latey', 'Henry Pickworth', 'John Whitehead', 'Rebecca Travers', 'Richard Hubberthorne', 'Silvanus Bevan', 'William Rogers'], ['Anthony Pearson', 'Dorcas Erbery', 'Edward Burrough', 'Francis Howgill', 'Gervase Benson', 'Hannah Stranger', 'James Nayler', 'John Crook', 'John Perrot', 'Joseph Wyeth', 'Martha Simmonds', 'Mary Fisher', 'Mary Prince', 'Richard Farnworth', 'Robert Rich', 'Thomas Aldam', 'Thomas Ellwood', 'William Crouch', 'William Dewsbury', 'William Tomlinson'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Anne Camm', 'Charles Marshall', 'Edward Pyott', 'John Audland', 'John Camm', 'John Penington', 'John Story', 'John Wilkinson', 'Mary Penington', 'Solomon Eccles', 'Thomas Camm', 'Thomas Curtis', 'William Simpson'], ['Fettiplace Bellers', 'John Bellers'], ['Anthony Sharp', 'James Claypoole', 'John Burnyeat', 'John ap John', 'Samuel Clarridge', 'William Edmundson'], ['Alexander Parker', 'Lewis Morris', 'Sir Charles Wager', 'Thomas Lawson'], ['Grace Chamber', 'Lydia Lancaster'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Elizabeth Leavens', 'Thomas Holme', 'William Gibson'], ['Gideon Wanton', 'John Wanton'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])
# Iteration 9
# (['Anne Conway Viscountess Conway and Killultagh', 'Benjamin Furly', 'David Barclay of Ury', 'Franciscus Mercurius van Helmont', 'George Keith', 'James Parnel', 'John Stubbs', 'John Swinton', 'Robert Barclay', 'Samuel Fisher', 'Stephen Crisp', 'William Ames', 'William Caton'], ['David Lloyd', 'Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'James Logan', 'Jane Sowle', 'John Bartram', 'Peter Collinson', 'Tace Sowle', 'Thomas Story', 'William Bradford', 'William Penn'], ['Elizabeth Hooten', 'Ellis Hookes', 'George Fox', 'George Fox the younger', 'Leonard Fell', 'Margaret Fell', 'Thomas Lower', 'Thomas Salthouse', 'William Coddington', 'William Mead', 'William Mucklow'], ['Alice Curwen', 'Daniel Quare', 'Francis Bugg', 'George Whitehead', 'Gilbert Latey', 'Henry Pickworth', 'John Whitehead', 'Rebecca Travers', 'Richard Hubberthorne', 'Silvanus Bevan', 'William Rogers'], ['Anthony Pearson', 'Dorcas Erbery', 'Edward Burrough', 'Francis Howgill', 'Gervase Benson', 'Hannah Stranger', 'James Nayler', 'John Crook', 'John Perrot', 'Joseph Wyeth', 'Martha Simmonds', 'Mary Fisher', 'Mary Prince', 'Richard Farnworth', 'Robert Rich', 'Thomas Aldam', 'Thomas Ellwood', 'William Crouch', 'William Dewsbury', 'William Tomlinson'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Anne Camm', 'Charles Marshall', 'Edward Pyott', 'John Audland', 'John Camm', 'John Penington', 'John Story', 'John Wilkinson', 'Mary Penington', 'Solomon Eccles', 'Thomas Camm', 'Thomas Curtis', 'William Simpson'], ['Fettiplace Bellers', 'John Bellers'], ['Anthony Sharp', 'James Claypoole', 'John Burnyeat', 'John ap John', 'Samuel Clarridge', 'William Edmundson'], ['Alexander Parker', 'Lewis Morris', 'Sir Charles Wager', 'Thomas Lawson'], ['Grace Chamber', 'Lydia Lancaster'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Elizabeth Leavens', 'Thomas Holme', 'William Gibson'], ['Gideon Wanton', 'John Wanton'], ['Joseph Besse', 'Richard Claridge', 'Samuel Bownas'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])
# Iteration 10
# (['Anne Conway Viscountess Conway and Killultagh', 'Benjamin Furly', 'David Barclay of Ury', 'Franciscus Mercurius van Helmont', 'George Keith', 'James Parnel', 'John Stubbs', 'John Swinton', 'Robert Barclay', 'Samuel Fisher', 'Stephen Crisp', 'William Ames', 'William Caton'], ['David Lloyd', 'Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'James Logan', 'Jane Sowle', 'John Bartram', 'Peter Collinson', 'Tace Sowle', 'Thomas Story', 'William Bradford', 'William Penn'], ['Elizabeth Hooten', 'Ellis Hookes', 'George Fox', 'George Fox the younger', 'Leonard Fell', 'Margaret Fell', 'Thomas Lower', 'Thomas Salthouse', 'William Coddington', 'William Mead', 'William Mucklow'], ['Alice Curwen', 'Daniel Quare', 'Francis Bugg', 'George Whitehead', 'Gilbert Latey', 'Henry Pickworth', 'John Whitehead', 'Rebecca Travers', 'Richard Hubberthorne', 'Silvanus Bevan', 'William Rogers'], ['Anthony Pearson', 'Dorcas Erbery', 'Edward Burrough', 'Francis Howgill', 'Gervase Benson', 'Hannah Stranger', 'James Nayler', 'John Crook', 'John Perrot', 'Joseph Wyeth', 'Martha Simmonds', 'Mary Fisher', 'Mary Prince', 'Richard Farnworth', 'Robert Rich', 'Thomas Aldam', 'Thomas Ellwood', 'William Crouch', 'William Dewsbury', 'William Tomlinson'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Anne Camm', 'Charles Marshall', 'Edward Pyott', 'John Audland', 'John Camm', 'John Story', 'John Wilkinson', 'Solomon Eccles', 'Thomas Camm'], ['Fettiplace Bellers', 'John Bellers'], ['Anthony Sharp', 'James Claypoole', 'John Burnyeat', 'John ap John', 'Samuel Clarridge', 'William Edmundson'], ['Alexander Parker', 'Lewis Morris', 'Sir Charles Wager', 'Thomas Lawson'], ['John Penington', 'Mary Penington', 'Thomas Curtis', 'William Simpson'], ['Grace Chamber', 'Lydia Lancaster'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Elizabeth Leavens', 'Thomas Holme', 'William Gibson'], ['Gideon Wanton', 'John Wanton'], ['Joseph Besse', 'Richard Claridge', 'Samuel Bownas'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])
# Iteration 11
# (['Anne Conway Viscountess Conway and Killultagh', 'Benjamin Furly', 'David Barclay of Ury', 'Franciscus Mercurius van Helmont', 'George Keith', 'James Parnel', 'John Stubbs', 'John Swinton', 'Robert Barclay', 'Samuel Fisher', 'Stephen Crisp', 'William Ames', 'William Caton'], ['David Lloyd', 'Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'James Logan', 'Jane Sowle', 'John Bartram', 'Peter Collinson', 'Tace Sowle', 'Thomas Story', 'William Bradford', 'William Penn'], ['Elizabeth Hooten', 'Ellis Hookes', 'George Fox', 'George Fox the younger', 'Leonard Fell', 'Margaret Fell', 'Thomas Lower', 'Thomas Salthouse', 'William Coddington', 'William Mead', 'William Mucklow'], ['Alice Curwen', 'Daniel Quare', 'Francis Bugg', 'George Whitehead', 'Gilbert Latey', 'Henry Pickworth', 'John Whitehead', 'Rebecca Travers', 'Richard Hubberthorne', 'Silvanus Bevan', 'William Rogers'], ['Edward Burrough', 'John Crook', 'John Perrot', 'Joseph Wyeth', 'Mary Fisher', 'Mary Prince', 'Thomas Ellwood', 'William Crouch', 'William Dewsbury'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Anthony Pearson', 'Dorcas Erbery', 'Francis Howgill', 'Gervase Benson', 'Hannah Stranger', 'James Nayler', 'Martha Simmonds', 'Richard Farnworth', 'Robert Rich', 'Thomas Aldam', 'William Tomlinson'], ['Anne Camm', 'Charles Marshall', 'Edward Pyott', 'John Audland', 'John Camm', 'John Story', 'John Wilkinson', 'Solomon Eccles', 'Thomas Camm'], ['Fettiplace Bellers', 'John Bellers'], ['Anthony Sharp', 'James Claypoole', 'John Burnyeat', 'John ap John', 'Samuel Clarridge', 'William Edmundson'], ['Alexander Parker', 'Lewis Morris', 'Sir Charles Wager', 'Thomas Lawson'], ['John Penington', 'Mary Penington', 'Thomas Curtis', 'William Simpson'], ['Grace Chamber', 'Lydia Lancaster'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Elizabeth Leavens', 'Thomas Holme', 'William Gibson'], ['Gideon Wanton', 'John Wanton'], ['Joseph Besse', 'Richard Claridge', 'Samuel Bownas'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])
# Iteration 12
# (['Anne Conway Viscountess Conway and Killultagh', 'Benjamin Furly', 'David Barclay of Ury', 'Franciscus Mercurius van Helmont', 'George Keith', 'James Parnel', 'John Stubbs', 'John Swinton', 'Robert Barclay', 'Samuel Fisher', 'Stephen Crisp', 'William Ames', 'William Caton'], ['Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'Jane Sowle', 'Tace Sowle', 'Thomas Story', 'William Bradford', 'William Penn'], ['Elizabeth Hooten', 'Ellis Hookes', 'George Fox', 'George Fox the younger', 'Leonard Fell', 'Margaret Fell', 'Thomas Lower', 'Thomas Salthouse', 'William Coddington', 'William Mead', 'William Mucklow'], ['Alice Curwen', 'Daniel Quare', 'Francis Bugg', 'George Whitehead', 'Gilbert Latey', 'Henry Pickworth', 'John Whitehead', 'Rebecca Travers', 'Richard Hubberthorne', 'Silvanus Bevan', 'William Rogers'], ['David Lloyd', 'James Logan', 'John Bartram', 'Peter Collinson'], ['Edward Burrough', 'John Crook', 'John Perrot', 'Joseph Wyeth', 'Mary Fisher', 'Mary Prince', 'Thomas Ellwood', 'William Crouch', 'William Dewsbury'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Anthony Pearson', 'Dorcas Erbery', 'Francis Howgill', 'Gervase Benson', 'Hannah Stranger', 'James Nayler', 'Martha Simmonds', 'Richard Farnworth', 'Robert Rich', 'Thomas Aldam', 'William Tomlinson'], ['Anne Camm', 'Charles Marshall', 'Edward Pyott', 'John Audland', 'John Camm', 'John Story', 'John Wilkinson', 'Solomon Eccles', 'Thomas Camm'], ['Fettiplace Bellers', 'John Bellers'], ['Anthony Sharp', 'James Claypoole', 'John Burnyeat', 'John ap John', 'Samuel Clarridge', 'William Edmundson'], ['Alexander Parker', 'Lewis Morris', 'Sir Charles Wager', 'Thomas Lawson'], ['John Penington', 'Mary Penington', 'Thomas Curtis', 'William Simpson'], ['Grace Chamber', 'Lydia Lancaster'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Elizabeth Leavens', 'Thomas Holme', 'William Gibson'], ['Gideon Wanton', 'John Wanton'], ['Joseph Besse', 'Richard Claridge', 'Samuel Bownas'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])
# Iteration 13
# (['Anne Conway Viscountess Conway and Killultagh', 'David Barclay of Ury', 'Franciscus Mercurius van Helmont', 'George Keith', 'John Swinton', 'Robert Barclay'], ['Benjamin Furly', 'James Parnel', 'John Stubbs', 'Samuel Fisher', 'Stephen Crisp', 'William Ames', 'William Caton'], ['Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'Jane Sowle', 'Tace Sowle', 'Thomas Story', 'William Bradford', 'William Penn'], ['Elizabeth Hooten', 'Ellis Hookes', 'George Fox', 'George Fox the younger', 'Leonard Fell', 'Margaret Fell', 'Thomas Lower', 'Thomas Salthouse', 'William Coddington', 'William Mead', 'William Mucklow'], ['Alice Curwen', 'Daniel Quare', 'Francis Bugg', 'George Whitehead', 'Gilbert Latey', 'Henry Pickworth', 'John Whitehead', 'Rebecca Travers', 'Richard Hubberthorne', 'Silvanus Bevan', 'William Rogers'], ['David Lloyd', 'James Logan', 'John Bartram', 'Peter Collinson'], ['Edward Burrough', 'John Crook', 'John Perrot', 'Joseph Wyeth', 'Mary Fisher', 'Mary Prince', 'Thomas Ellwood', 'William Crouch', 'William Dewsbury'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Anthony Pearson', 'Dorcas Erbery', 'Francis Howgill', 'Gervase Benson', 'Hannah Stranger', 'James Nayler', 'Martha Simmonds', 'Richard Farnworth', 'Robert Rich', 'Thomas Aldam', 'William Tomlinson'], ['Anne Camm', 'Charles Marshall', 'Edward Pyott', 'John Audland', 'John Camm', 'John Story', 'John Wilkinson', 'Solomon Eccles', 'Thomas Camm'], ['Fettiplace Bellers', 'John Bellers'], ['Anthony Sharp', 'James Claypoole', 'John Burnyeat', 'John ap John', 'Samuel Clarridge', 'William Edmundson'], ['Alexander Parker', 'Lewis Morris', 'Sir Charles Wager', 'Thomas Lawson'], ['John Penington', 'Mary Penington', 'Thomas Curtis', 'William Simpson'], ['Grace Chamber', 'Lydia Lancaster'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Elizabeth Leavens', 'Thomas Holme', 'William Gibson'], ['Gideon Wanton', 'John Wanton'], ['Joseph Besse', 'Richard Claridge', 'Samuel Bownas'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])
# Iteration 14
# (['Anne Conway Viscountess Conway and Killultagh', 'David Barclay of Ury', 'Franciscus Mercurius van Helmont', 'George Keith', 'John Swinton', 'Robert Barclay'], ['Benjamin Furly', 'James Parnel', 'John Stubbs', 'Samuel Fisher', 'Stephen Crisp', 'William Ames', 'William Caton'], ['Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'Jane Sowle', 'Tace Sowle', 'Thomas Story', 'William Bradford', 'William Penn'], ['Elizabeth Hooten', 'Ellis Hookes', 'George Fox', 'George Fox the younger', 'Leonard Fell', 'Margaret Fell', 'Thomas Lower', 'Thomas Salthouse', 'William Coddington', 'William Mead', 'William Mucklow'], ['Alice Curwen', 'Daniel Quare', 'George Whitehead', 'Gilbert Latey', 'John Whitehead', 'Rebecca Travers', 'Richard Hubberthorne', 'Silvanus Bevan', 'William Rogers'], ['David Lloyd', 'James Logan', 'John Bartram', 'Peter Collinson'], ['Edward Burrough', 'John Crook', 'John Perrot', 'Joseph Wyeth', 'Mary Fisher', 'Mary Prince', 'Thomas Ellwood', 'William Crouch', 'William Dewsbury'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Anthony Pearson', 'Dorcas Erbery', 'Francis Howgill', 'Gervase Benson', 'Hannah Stranger', 'James Nayler', 'Martha Simmonds', 'Richard Farnworth', 'Robert Rich', 'Thomas Aldam', 'William Tomlinson'], ['Anne Camm', 'Charles Marshall', 'Edward Pyott', 'John Audland', 'John Camm', 'John Story', 'John Wilkinson', 'Solomon Eccles', 'Thomas Camm'], ['Fettiplace Bellers', 'John Bellers'], ['Anthony Sharp', 'James Claypoole', 'John Burnyeat', 'John ap John', 'Samuel Clarridge', 'William Edmundson'], ['Alexander Parker', 'Lewis Morris', 'Sir Charles Wager', 'Thomas Lawson'], ['John Penington', 'Mary Penington', 'Thomas Curtis', 'William Simpson'], ['Grace Chamber', 'Lydia Lancaster'], ['Francis Bugg', 'Henry Pickworth'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Elizabeth Leavens', 'Thomas Holme', 'William Gibson'], ['Gideon Wanton', 'John Wanton'], ['Joseph Besse', 'Richard Claridge', 'Samuel Bownas'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])
# Iteration 15
# (['Anne Conway Viscountess Conway and Killultagh', 'David Barclay of Ury', 'Franciscus Mercurius van Helmont', 'George Keith', 'John Swinton', 'Robert Barclay'], ['Benjamin Furly', 'James Parnel', 'John Stubbs', 'Samuel Fisher', 'Stephen Crisp', 'William Ames', 'William Caton'], ['Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'Jane Sowle', 'Tace Sowle', 'Thomas Story', 'William Bradford', 'William Penn'], ['Elizabeth Hooten', 'Ellis Hookes', 'George Fox', 'Leonard Fell', 'William Coddington', 'William Mucklow'], ['Alice Curwen', 'Daniel Quare', 'George Whitehead', 'Gilbert Latey', 'John Whitehead', 'Rebecca Travers', 'Richard Hubberthorne', 'Silvanus Bevan', 'William Rogers'], ['David Lloyd', 'James Logan', 'John Bartram', 'Peter Collinson'], ['Edward Burrough', 'John Crook', 'John Perrot', 'Joseph Wyeth', 'Mary Fisher', 'Mary Prince', 'Thomas Ellwood', 'William Crouch', 'William Dewsbury'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Anthony Pearson', 'Dorcas Erbery', 'Francis Howgill', 'Gervase Benson', 'Hannah Stranger', 'James Nayler', 'Martha Simmonds', 'Richard Farnworth', 'Robert Rich', 'Thomas Aldam', 'William Tomlinson'], ['Anne Camm', 'Charles Marshall', 'Edward Pyott', 'John Audland', 'John Camm', 'John Story', 'John Wilkinson', 'Solomon Eccles', 'Thomas Camm'], ['Fettiplace Bellers', 'John Bellers'], ['George Fox the younger', 'Margaret Fell', 'Thomas Lower', 'Thomas Salthouse', 'William Mead'], ['Anthony Sharp', 'James Claypoole', 'John Burnyeat', 'John ap John', 'Samuel Clarridge', 'William Edmundson'], ['Alexander Parker', 'Lewis Morris', 'Sir Charles Wager', 'Thomas Lawson'], ['John Penington', 'Mary Penington', 'Thomas Curtis', 'William Simpson'], ['Grace Chamber', 'Lydia Lancaster'], ['Francis Bugg', 'Henry Pickworth'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Elizabeth Leavens', 'Thomas Holme', 'William Gibson'], ['Gideon Wanton', 'John Wanton'], ['Joseph Besse', 'Richard Claridge', 'Samuel Bownas'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])
# Iteration 16
# (['Anne Conway Viscountess Conway and Killultagh', 'David Barclay of Ury', 'Franciscus Mercurius van Helmont', 'George Keith', 'John Swinton', 'Robert Barclay'], ['Benjamin Furly', 'James Parnel', 'John Stubbs', 'Samuel Fisher', 'Stephen Crisp', 'William Ames', 'William Caton'], ['Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'Jane Sowle', 'Tace Sowle', 'Thomas Story', 'William Bradford', 'William Penn'], ['Elizabeth Hooten', 'Ellis Hookes', 'George Fox', 'Leonard Fell', 'William Coddington', 'William Mucklow'], ['Alice Curwen', 'George Whitehead', 'Gilbert Latey', 'John Whitehead', 'Rebecca Travers', 'Richard Hubberthorne', 'William Rogers'], ['David Lloyd', 'James Logan', 'John Bartram', 'Peter Collinson'], ['Edward Burrough', 'John Crook', 'John Perrot', 'Joseph Wyeth', 'Mary Fisher', 'Mary Prince', 'Thomas Ellwood', 'William Crouch', 'William Dewsbury'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Anthony Pearson', 'Dorcas Erbery', 'Francis Howgill', 'Gervase Benson', 'Hannah Stranger', 'James Nayler', 'Martha Simmonds', 'Richard Farnworth', 'Robert Rich', 'Thomas Aldam', 'William Tomlinson'], ['Anne Camm', 'Charles Marshall', 'Edward Pyott', 'John Audland', 'John Camm', 'John Story', 'John Wilkinson', 'Solomon Eccles', 'Thomas Camm'], ['Fettiplace Bellers', 'John Bellers'], ['George Fox the younger', 'Margaret Fell', 'Thomas Lower', 'Thomas Salthouse', 'William Mead'], ['Anthony Sharp', 'James Claypoole', 'John Burnyeat', 'John ap John', 'Samuel Clarridge', 'William Edmundson'], ['Alexander Parker', 'Lewis Morris', 'Sir Charles Wager', 'Thomas Lawson'], ['John Penington', 'Mary Penington', 'Thomas Curtis', 'William Simpson'], ['Grace Chamber', 'Lydia Lancaster'], ['Francis Bugg', 'Henry Pickworth'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Elizabeth Leavens', 'Thomas Holme', 'William Gibson'], ['Gideon Wanton', 'John Wanton'], ['Joseph Besse', 'Richard Claridge', 'Samuel Bownas'], ['Daniel Quare', 'Silvanus Bevan'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])
# Iteration 17
# (['Anne Conway Viscountess Conway and Killultagh', 'David Barclay of Ury', 'Franciscus Mercurius van Helmont', 'George Keith', 'John Swinton', 'Robert Barclay'], ['Benjamin Furly', 'James Parnel', 'John Stubbs', 'Samuel Fisher', 'Stephen Crisp', 'William Ames', 'William Caton'], ['Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'Jane Sowle', 'Tace Sowle', 'Thomas Story', 'William Bradford', 'William Penn'], ['Elizabeth Hooten', 'Ellis Hookes', 'George Fox', 'Leonard Fell', 'William Coddington', 'William Mucklow'], ['Alice Curwen', 'George Whitehead', 'Gilbert Latey', 'John Whitehead', 'Rebecca Travers', 'Richard Hubberthorne', 'William Rogers'], ['David Lloyd', 'James Logan', 'John Bartram', 'Peter Collinson'], ['Joseph Wyeth', 'Thomas Ellwood'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Anthony Pearson', 'Dorcas Erbery', 'Francis Howgill', 'Gervase Benson', 'Hannah Stranger', 'James Nayler', 'Martha Simmonds', 'Richard Farnworth', 'Robert Rich', 'Thomas Aldam', 'William Tomlinson'], ['Edward Burrough', 'John Crook', 'John Perrot', 'Mary Fisher', 'Mary Prince', 'William Crouch', 'William Dewsbury'], ['Anne Camm', 'Charles Marshall', 'Edward Pyott', 'John Audland', 'John Camm', 'John Story', 'John Wilkinson', 'Solomon Eccles', 'Thomas Camm'], ['Fettiplace Bellers', 'John Bellers'], ['George Fox the younger', 'Margaret Fell', 'Thomas Lower', 'Thomas Salthouse', 'William Mead'], ['Anthony Sharp', 'James Claypoole', 'John Burnyeat', 'John ap John', 'Samuel Clarridge', 'William Edmundson'], ['Alexander Parker', 'Lewis Morris', 'Sir Charles Wager', 'Thomas Lawson'], ['John Penington', 'Mary Penington', 'Thomas Curtis', 'William Simpson'], ['Grace Chamber', 'Lydia Lancaster'], ['Francis Bugg', 'Henry Pickworth'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Elizabeth Leavens', 'Thomas Holme', 'William Gibson'], ['Gideon Wanton', 'John Wanton'], ['Joseph Besse', 'Richard Claridge', 'Samuel Bownas'], ['Daniel Quare', 'Silvanus Bevan'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])
# Iteration 18
# (['Anne Conway Viscountess Conway and Killultagh', 'David Barclay of Ury', 'Franciscus Mercurius van Helmont', 'George Keith', 'John Swinton', 'Robert Barclay'], ['Benjamin Furly', 'James Parnel', 'John Stubbs', 'Samuel Fisher', 'Stephen Crisp', 'William Ames', 'William Caton'], ['Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'Jane Sowle', 'Tace Sowle', 'Thomas Story', 'William Bradford', 'William Penn'], ['Elizabeth Hooten', 'Ellis Hookes', 'George Fox', 'Leonard Fell', 'William Coddington', 'William Mucklow'], ['Alice Curwen', 'George Whitehead', 'Gilbert Latey', 'John Whitehead', 'Rebecca Travers', 'Richard Hubberthorne', 'William Rogers'], ['David Lloyd', 'James Logan', 'John Bartram', 'Peter Collinson'], ['Joseph Wyeth', 'Thomas Ellwood'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Dorcas Erbery', 'Francis Howgill', 'Hannah Stranger', 'James Nayler', 'Martha Simmonds', 'Richard Farnworth', 'Robert Rich', 'William Tomlinson'], ['Edward Burrough', 'John Crook', 'John Perrot', 'Mary Fisher', 'Mary Prince', 'William Crouch', 'William Dewsbury'], ['Anne Camm', 'Charles Marshall', 'Edward Pyott', 'John Audland', 'John Camm', 'John Story', 'John Wilkinson', 'Solomon Eccles', 'Thomas Camm'], ['Fettiplace Bellers', 'John Bellers'], ['George Fox the younger', 'Margaret Fell', 'Thomas Lower', 'Thomas Salthouse', 'William Mead'], ['Anthony Sharp', 'James Claypoole', 'John Burnyeat', 'John ap John', 'Samuel Clarridge', 'William Edmundson'], ['Alexander Parker', 'Lewis Morris', 'Sir Charles Wager', 'Thomas Lawson'], ['Anthony Pearson', 'Gervase Benson', 'Thomas Aldam'], ['John Penington', 'Mary Penington', 'Thomas Curtis', 'William Simpson'], ['Grace Chamber', 'Lydia Lancaster'], ['Francis Bugg', 'Henry Pickworth'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Elizabeth Leavens', 'Thomas Holme', 'William Gibson'], ['Gideon Wanton', 'John Wanton'], ['Joseph Besse', 'Richard Claridge', 'Samuel Bownas'], ['Daniel Quare', 'Silvanus Bevan'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])
# Iteration 19
# (['Anne Conway Viscountess Conway and Killultagh', 'David Barclay of Ury', 'Franciscus Mercurius van Helmont', 'George Keith', 'John Swinton', 'Robert Barclay'], ['Benjamin Furly', 'James Parnel', 'John Stubbs', 'Samuel Fisher', 'Stephen Crisp', 'William Ames', 'William Caton'], ['Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'Thomas Story', 'William Penn'], ['Elizabeth Hooten', 'Ellis Hookes', 'George Fox', 'Leonard Fell', 'William Coddington', 'William Mucklow'], ['Alice Curwen', 'George Whitehead', 'Gilbert Latey', 'John Whitehead', 'Rebecca Travers', 'Richard Hubberthorne', 'William Rogers'], ['Jane Sowle', 'Tace Sowle', 'William Bradford'], ['David Lloyd', 'James Logan', 'John Bartram', 'Peter Collinson'], ['Joseph Wyeth', 'Thomas Ellwood'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Dorcas Erbery', 'Francis Howgill', 'Hannah Stranger', 'James Nayler', 'Martha Simmonds', 'Richard Farnworth', 'Robert Rich', 'William Tomlinson'], ['Edward Burrough', 'John Crook', 'John Perrot', 'Mary Fisher', 'Mary Prince', 'William Crouch', 'William Dewsbury'], ['Anne Camm', 'Charles Marshall', 'Edward Pyott', 'John Audland', 'John Camm', 'John Story', 'John Wilkinson', 'Solomon Eccles', 'Thomas Camm'], ['Fettiplace Bellers', 'John Bellers'], ['George Fox the younger', 'Margaret Fell', 'Thomas Lower', 'Thomas Salthouse', 'William Mead'], ['Anthony Sharp', 'James Claypoole', 'John Burnyeat', 'John ap John', 'Samuel Clarridge', 'William Edmundson'], ['Alexander Parker', 'Lewis Morris', 'Sir Charles Wager', 'Thomas Lawson'], ['Anthony Pearson', 'Gervase Benson', 'Thomas Aldam'], ['John Penington', 'Mary Penington', 'Thomas Curtis', 'William Simpson'], ['Grace Chamber', 'Lydia Lancaster'], ['Francis Bugg', 'Henry Pickworth'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Elizabeth Leavens', 'Thomas Holme', 'William Gibson'], ['Gideon Wanton', 'John Wanton'], ['Joseph Besse', 'Richard Claridge', 'Samuel Bownas'], ['Daniel Quare', 'Silvanus Bevan'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])
# Iteration 20
# (['Anne Conway Viscountess Conway and Killultagh', 'David Barclay of Ury', 'Franciscus Mercurius van Helmont', 'George Keith', 'John Swinton', 'Robert Barclay'], ['Benjamin Furly', 'James Parnel', 'John Stubbs', 'Samuel Fisher', 'Stephen Crisp', 'William Ames', 'William Caton'], ['Edward Haistwell', 'Isaac Norris', 'Isabel Yeamans', 'Thomas Story', 'William Penn'], ['Elizabeth Hooten', 'Ellis Hookes', 'George Fox', 'Leonard Fell', 'William Coddington', 'William Mucklow'], ['George Whitehead', 'Gilbert Latey', 'John Whitehead', 'Richard Hubberthorne', 'William Rogers'], ['Jane Sowle', 'Tace Sowle', 'William Bradford'], ['David Lloyd', 'James Logan', 'John Bartram', 'Peter Collinson'], ['Joseph Wyeth', 'Thomas Ellwood'], ['Alexander Skene of Newtyle', 'Lilias Skene'], ['Dorcas Erbery', 'Francis Howgill', 'Hannah Stranger', 'James Nayler', 'Martha Simmonds', 'Richard Farnworth', 'Robert Rich', 'William Tomlinson'], ['Edward Burrough', 'John Crook', 'John Perrot', 'Mary Fisher', 'Mary Prince', 'William Crouch', 'William Dewsbury'], ['Anne Camm', 'Charles Marshall', 'Edward Pyott', 'John Audland', 'John Camm', 'John Story', 'John Wilkinson', 'Solomon Eccles', 'Thomas Camm'], ['Fettiplace Bellers', 'John Bellers'], ['George Fox the younger', 'Margaret Fell', 'Thomas Lower', 'Thomas Salthouse', 'William Mead'], ['Anthony Sharp', 'James Claypoole', 'John Burnyeat', 'John ap John', 'Samuel Clarridge', 'William Edmundson'], ['Alexander Parker', 'Lewis Morris', 'Sir Charles Wager', 'Thomas Lawson'], ['Anthony Pearson', 'Gervase Benson', 'Thomas Aldam'], ['Alice Curwen', 'Rebecca Travers'], ['John Penington', 'Mary Penington', 'Thomas Curtis', 'William Simpson'], ['Grace Chamber', 'Lydia Lancaster'], ['Francis Bugg', 'Henry Pickworth'], ['Dorothy Waugh', 'Sarah Gibbons'], ['David Barclay', 'John Freame'], ['Humphrey Norton', 'John Rous'], ['Elizabeth Leavens', 'Thomas Holme', 'William Gibson'], ['Gideon Wanton', 'John Wanton'], ['Joseph Besse', 'Richard Claridge', 'Samuel Bownas'], ['Daniel Quare', 'Silvanus Bevan'], ['Katharine Evans', 'Sarah Cheevers'], ['Christopher Taylor', 'John Whiting', 'Thomas Taylor'], ['Humphrey Woolrich', 'Mary Pennyman'], ['George Bishop', 'Richard Vickris'])

# %% [markdown]
# ### 3

# %%
quakerG
# Out:
# {'Role': 'Quaker schismatic and Church of England clergyman',
#  'Gender': 'male',
#  'Birthdate': 1638,
#  'Deathdate': 1716,
#  'Quaker': True,
#  'katz': 0.16572417573149956,
#  'betweenness': 0.04500656400917155,
#  'louvain': 0}

# %%
nx.attribute_assortativity_coefficient(quakerG,'Role')
# Out:
# 0.03313315386208324

# %% [markdown]
# **Quiz A: Given the following adjacency matrix of a graph:**
#
# <img src="imgs/quizA.png">
#
# 1. A is a directed graph with average in-degree 4/3
# 2. A is an undirected graph with average degree 4/3
# 3. A is a directed graph with average in-degree 1
# 4. A is an undirected graph with average degree 1

# %% [markdown]
# __sol: 1.__
#
# 0 -> 1 <br>
# 1 -> 2 <br>
# 2 -> 0 <br>
# 2 -> 1 <br>
#
# => (1 + 1 + 2) / 3

# %% [markdown]
# **Quiz B: In a horror scenario, your lost luggage is landing at an airport and being loaded to another random flight and transferred to another airport. This has been going on for months. Given a very large number of iterations, which of the following metrics gives you the probability that your luggage ends up in Geneva airport?**
#
# 1. Closeness centrality
# 2. Page rank
# 3. Betweenness centrality
# 4. Katz similarity

# %% [markdown]
# __sol: 2.__

# %% [markdown]
# ### Take it further
# Course at Stanford taught by Jure Leskovec: http://web.stanford.edu/class/cs224w/
#
# (Better) alternative to NetworkX, see igraph: http://igraph.org/python/
#
# For larger graph analysis:
#
# * Apache GraphX: https://spark.apache.org/graphx/
# * Apache Giraph: http://giraph.apache.org
# * Webgraph: http://webgraph.di.unimi.it/
# * SNAP: http://snap.stanford.edu/snap/
# * Graph tool: https://graph-tool.skewed.de
# * Network kit: https://networkit.iti.kit.edu/api/structures.html
# * Pajek: http://mrvar.fdv.uni-lj.si/pajek/
# * Network Workbench: http://nwb.cns.iu.edu
